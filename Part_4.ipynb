# %%
import pandas as pd
from itertools import combinations
import time
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
from mlxtend.frequent_patterns import association_rules as arules

# %%
# Function to generate frequent itemsets using brute-force method
def generate_frequent_itemsets_bruteforce(transactions, min_support):
    item_counts = {}
    for transaction in transactions:
        for item in transaction:
            if item in item_counts:
                item_counts[item] += 1
            else:
                item_counts[item] = 1

    frequent_itemsets = []
    for item, count in item_counts.items():
        support = count / len(transactions)
        if support >= min_support:
            frequent_itemsets.append({item})

    k = 2
    while True:
        candidate_itemsets = set(combinations(item_counts.keys(), k))
        frequent_itemsets_k = []
        for candidate in candidate_itemsets:
            support = sum(1 for transaction in transactions if set(candidate).issubset(set(transaction))) / len(transactions)
            if support >= min_support:
                frequent_itemsets_k.append(set(candidate))
        if not frequent_itemsets_k:
            break
        frequent_itemsets.extend(frequent_itemsets_k)
        k += 1

    return frequent_itemsets

# Function to convert transactions into a boolean DataFrame
def create_boolean_df(transactions):
    unique_items = sorted(set(item for sublist in transactions for item in sublist))
    boolean_df = pd.DataFrame(0, columns=unique_items, index=range(len(transactions)))
    for i, transaction in enumerate(transactions):
        boolean_df.loc[i, transaction] = 1
    return boolean_df
# Function to generate association rules
def generate_association_rules(frequent_itemsets, min_confidence):
    association_rules = []
    for itemset in frequent_itemsets:
        if len(itemset) >= 2:
            for i in range(1, len(itemset)):
                for antecedent in combinations(itemset, i):
                    antecedent = set(antecedent)
                    consequent = itemset - antecedent
                    antecedent_support = sum(1 for itemset in frequent_itemsets if antecedent.issubset(itemset)) / len(frequent_itemsets)
                    rule_confidence = len(itemset) / len(antecedent)
                    if rule_confidence >= min_confidence:
                        association_rules.append((antecedent, consequent, antecedent_support, rule_confidence))
    return association_rules

# Function to generate association rules using Apriori algorithm
def generate_association_rules_apriori(transactions, min_support, min_confidence):
    df = create_boolean_df(transactions)
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    rules = arules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    return rules

# Function to generate association rules using FP-Growth algorithm
def generate_association_rules_fpgrowth(transactions, min_support, min_confidence):
    df = create_boolean_df(transactions)
    frequent_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
    rules = arules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    return rules

# Set minimum support and confidence
min_support = 0.2
min_confidence = 0.7
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Load transactions from CSV files for each dataset
amazon_transactions = pd.read_csv("amazon_transactions.csv")['Transaction'].apply(lambda x: x.split(", ")).tolist()
best_buy_transactions = pd.read_csv("best_buy_transactions.csv")['Transaction'].apply(lambda x: x.split(", ")).tolist()
k_mart_transactions = pd.read_csv("k_mart_transactions.csv")['Transaction'].apply(lambda x: x.split(", ")).tolist()
nike_transactions = pd.read_csv("nike_transactions.csv")['Transaction'].apply(lambda x: x.split(", ")).tolist()
flipkart_transactions = pd.read_csv("flipkart_transactions.csv")['Transaction'].apply(lambda x: x.split(", ")).tolist()

# Timing performance and generating association rules for each dataset
datasets = {
    "Amazon": amazon_transactions,
    "Best Buy": best_buy_transactions,
    "K-mart": k_mart_transactions,
    "Nike": nike_transactions,
    "Flipkart": flipkart_transactions
}
for dataset_name, dataset_transactions in datasets.items():
    frequent_itemsets = generate_frequent_itemsets_bruteforce(dataset_transactions, min_support)
    association_rules = generate_association_rules(frequent_itemsets, min_confidence)
    print(f"\n{dataset_name} Frequent Itemsets:")
    for itemset in frequent_itemsets:
        print(itemset)
    print(f"\n{dataset_name} Association Rules:")
    for rule in association_rules:
        print(rule)

for dataset_name, dataset_transactions in datasets.items():
    print(f"\n{dataset_name} Timing Performance:")

    # Brute-force method
    start_time = time.time()
    brute_force_frequent_itemsets = generate_frequent_itemsets_bruteforce(dataset_transactions, min_support)
    brute_force_execution_time = time.time() - start_time
    print("Brute-force Execution Time:", brute_force_execution_time, "seconds")

    # Apriori algorithm
    start_time = time.time()
    apriori_association_rules = generate_association_rules_apriori(dataset_transactions, min_support, min_confidence)
    apriori_execution_time = time.time() - start_time
    print("Apriori Execution Time:", apriori_execution_time, "seconds")

    # FP-Growth algorithm
    start_time = time.time()
    fpgrowth_association_rules = generate_association_rules_fpgrowth(dataset_transactions, min_support, min_confidence)
    fpgrowth_execution_time = time.time() - start_time
    print("FP-Growth Execution Time:", fpgrowth_execution_time, "seconds")

    # Print association rules for each algorithm
    print(f"\n{dataset_name} Association Rules:")
    print("Brute-force:")
    print(brute_force_frequent_itemsets)
    print("Apriori:")
    print(apriori_association_rules)
    print("FP-Growth:")
    print(fpgrowth_association_rules)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Amazon Frequent Itemsets:
# {"['A Beginner’s Guide'"}
# {"'Java: The Complete Reference'"}
# {"'Java For Dummies'"}
# {"'Android Programming: The Big Nerd Ranch']"}
# {"'Android Programming: The Big Nerd Ranch'"}
# {"'Head First Java 2nd Edition']"}
# {"'Java: The Complete Reference'", "'Java For Dummies'"}
# {"'Java: The Complete Reference'", "['A Beginner’s Guide'"}
# {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}
# {"['A Beginner’s Guide'", "'Java For Dummies'"}
# {"'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}
# {"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}
# {"'Java: The Complete Reference'", "['A Beginner’s Guide'", "'Java For Dummies'"}
# {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}
# {"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'", "'Java For Dummies'"}
# {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}
# {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'", "'Java For Dummies'"}
#
# Amazon Association Rules:
# ({"'Java: The Complete Reference'"}, {"'Java For Dummies'"}, 0.47058823529411764, 2.0)
# ({"'Java For Dummies'"}, {"'Java: The Complete Reference'"}, 0.47058823529411764, 2.0)
# ({"'Java: The Complete Reference'"}, {"['A Beginner’s Guide'"}, 0.47058823529411764, 2.0)
# ({"['A Beginner’s Guide'"}, {"'Java: The Complete Reference'"}, 0.47058823529411764, 2.0)
# ({"'Java: The Complete Reference'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 2.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"'Java: The Complete Reference'"}, 0.47058823529411764, 2.0)
# ({"['A Beginner’s Guide'"}, {"'Java For Dummies'"}, 0.47058823529411764, 2.0)
# ({"'Java For Dummies'"}, {"['A Beginner’s Guide'"}, 0.47058823529411764, 2.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"'Java For Dummies'"}, 0.47058823529411764, 2.0)
# ({"'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 2.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'"}, 0.47058823529411764, 2.0)
# ({"['A Beginner’s Guide'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 2.0)
# ({"'Java: The Complete Reference'"}, {"['A Beginner’s Guide'", "'Java For Dummies'"}, 0.47058823529411764, 3.0)
# ({"['A Beginner’s Guide'"}, {"'Java: The Complete Reference'", "'Java For Dummies'"}, 0.47058823529411764, 3.0)
# ({"'Java For Dummies'"}, {"'Java: The Complete Reference'", "['A Beginner’s Guide'"}, 0.47058823529411764, 3.0)
# ({"'Java: The Complete Reference'", "['A Beginner’s Guide'"}, {"'Java For Dummies'"}, 0.23529411764705882, 1.5)
# ({"'Java: The Complete Reference'", "'Java For Dummies'"}, {"['A Beginner’s Guide'"}, 0.23529411764705882, 1.5)
# ({"['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Java: The Complete Reference'"}, 0.23529411764705882, 1.5)
# ({"'Java: The Complete Reference'"}, {"'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}, 0.47058823529411764, 3.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"'Java: The Complete Reference'", "'Java For Dummies'"}, 0.47058823529411764, 3.0)
# ({"'Java For Dummies'"}, {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 3.0)
# ({"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, {"'Java For Dummies'"}, 0.23529411764705882, 1.5)
# ({"'Java: The Complete Reference'", "'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 1.5)
# ({"'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}, {"'Java: The Complete Reference'"}, 0.23529411764705882, 1.5)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'", "'Java For Dummies'"}, 0.47058823529411764, 3.0)
# ({"['A Beginner’s Guide'"}, {"'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}, 0.47058823529411764, 3.0)
# ({"'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}, 0.47058823529411764, 3.0)
# ({"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}, {"'Java For Dummies'"}, 0.23529411764705882, 1.5)
# ({"'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}, {"['A Beginner’s Guide'"}, 0.23529411764705882, 1.5)
# ({"['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 1.5)
# ({"'Java: The Complete Reference'"}, {"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}, 0.47058823529411764, 3.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"'Java: The Complete Reference'", "['A Beginner’s Guide'"}, 0.47058823529411764, 3.0)
# ({"['A Beginner’s Guide'"}, {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 3.0)
# ({"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'"}, 0.23529411764705882, 1.5)
# ({"'Java: The Complete Reference'", "['A Beginner’s Guide'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 1.5)
# ({"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}, {"'Java: The Complete Reference'"}, 0.23529411764705882, 1.5)
# ({"'Java: The Complete Reference'"}, {"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'", "'Java For Dummies'"}, 0.47058823529411764, 4.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"'Java: The Complete Reference'", "['A Beginner’s Guide'", "'Java For Dummies'"}, 0.47058823529411764, 4.0)
# ({"['A Beginner’s Guide'"}, {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}, 0.47058823529411764, 4.0)
# ({"'Java For Dummies'"}, {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}, 0.47058823529411764, 4.0)
# ({"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'", "'Java For Dummies'"}, 0.23529411764705882, 2.0)
# ({"'Java: The Complete Reference'", "['A Beginner’s Guide'"}, {"'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}, 0.23529411764705882, 2.0)
# ({"'Java: The Complete Reference'", "'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}, 0.23529411764705882, 2.0)
# ({"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}, {"'Java: The Complete Reference'", "'Java For Dummies'"}, 0.23529411764705882, 2.0)
# ({"'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}, {"'Java: The Complete Reference'", "['A Beginner’s Guide'"}, 0.23529411764705882, 2.0)
# ({"['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 2.0)
# ({"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'"}, {"'Java For Dummies'"}, 0.11764705882352941, 1.3333333333333333)
# ({"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']", "'Java For Dummies'"}, {"['A Beginner’s Guide'"}, 0.11764705882352941, 1.3333333333333333)
# ({"'Java: The Complete Reference'", "['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.11764705882352941, 1.3333333333333333)
# ({"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Java: The Complete Reference'"}, 0.11764705882352941, 1.3333333333333333)
#
# Best Buy Frequent Itemsets:
# {"'Printer'"}
# {"'Flash Drive'"}
# {"'Microsoft Office'"}
# {"'Speakers'"}
# {"'Anti-Virus']"}
# {"['Lab Top'"}
# {"'Lab Top Case'"}
# {"'Anti-Virus'"}
# {"'External Hard Drive'"}
# {"['Digital Camera'"}
# {"'Lab Top'"}
# {"'Speakers']"}
# {"'Anti-Virus']", "['Lab Top'"}
# {"'Microsoft Office'", "'Speakers'"}
# {"['Digital Camera'", "'Flash Drive'"}
# {"'Anti-Virus'", "'Printer'"}
# {"'Lab Top Case'", "'Microsoft Office'"}
# {"'Lab Top Case'", "'Flash Drive'"}
# {"'Anti-Virus']", "'Lab Top Case'"}
# {"'Anti-Virus'", "'External Hard Drive'"}
# {"'Lab Top Case'", "'Speakers'"}
# {"'Lab Top Case'", "['Lab Top'"}
# {"['Digital Camera'", "'Speakers']"}
# {"'Anti-Virus']", "'Flash Drive'"}
# {"'Anti-Virus'", "'Flash Drive'"}
# {"'Anti-Virus'", "'Lab Top Case'"}
# {"'Anti-Virus'", "['Digital Camera'"}
# {"'Lab Top Case'", "'Speakers']"}
# {"['Digital Camera'", "'Lab Top'"}
# {"'Microsoft Office'", "'Printer'"}
# {"'Lab Top Case'", "'Printer'"}
# {"'Speakers'", "'Flash Drive'"}
# {"'Anti-Virus'", "'Microsoft Office'"}
# {"'Lab Top Case'", "'External Hard Drive'"}
# {"'Microsoft Office'", "'Flash Drive'"}
# {"'Flash Drive'", "['Lab Top'"}
# {"['Digital Camera'", "'Lab Top Case'"}
# {"'Printer'", "'Flash Drive'"}
# {"['Digital Camera'", "'Lab Top Case'", "'Speakers']"}
# {"'Anti-Virus'", "'Microsoft Office'", "'Flash Drive'"}
# {"'Lab Top Case'", "'Printer'", "'Flash Drive'"}
# {"'Anti-Virus'", "'Lab Top Case'", "'Flash Drive'"}
# {"'Microsoft Office'", "'Printer'", "'Flash Drive'"}
# {"'Lab Top Case'", "'Microsoft Office'", "'Flash Drive'"}
# {"'Anti-Virus'", "'Lab Top Case'", "'Microsoft Office'"}
# {"'Microsoft Office'", "'Lab Top Case'", "'Printer'"}
# {"'Anti-Virus'", "'Printer'", "'Flash Drive'"}
# {"'Microsoft Office'", "'Speakers'", "'Flash Drive'"}
# {"'Anti-Virus'", "'Lab Top Case'", "'Microsoft Office'", "'Flash Drive'"}
# {"'Microsoft Office'", "'Lab Top Case'", "'Printer'", "'Flash Drive'"}
#
# Best Buy Association Rules:
# ({"'Anti-Virus']"}, {"['Lab Top'"}, 0.08, 2.0)
# ({"['Lab Top'"}, {"'Anti-Virus']"}, 0.08, 2.0)
# ({"'Microsoft Office'"}, {"'Speakers'"}, 0.28, 2.0)
# ({"'Speakers'"}, {"'Microsoft Office'"}, 0.1, 2.0)
# ({"['Digital Camera'"}, {"'Flash Drive'"}, 0.14, 2.0)
# ({"'Flash Drive'"}, {"['Digital Camera'"}, 0.36, 2.0)
# ({"'Anti-Virus'"}, {"'Printer'"}, 0.24, 2.0)
# ({"'Printer'"}, {"'Anti-Virus'"}, 0.2, 2.0)
# ({"'Lab Top Case'"}, {"'Microsoft Office'"}, 0.38, 2.0)
# ({"'Microsoft Office'"}, {"'Lab Top Case'"}, 0.28, 2.0)
# ({"'Lab Top Case'"}, {"'Flash Drive'"}, 0.38, 2.0)
# ({"'Flash Drive'"}, {"'Lab Top Case'"}, 0.36, 2.0)
# ({"'Anti-Virus']"}, {"'Lab Top Case'"}, 0.08, 2.0)
# ({"'Lab Top Case'"}, {"'Anti-Virus']"}, 0.38, 2.0)
# ({"'Anti-Virus'"}, {"'External Hard Drive'"}, 0.24, 2.0)
# ({"'External Hard Drive'"}, {"'Anti-Virus'"}, 0.06, 2.0)
# ({"'Lab Top Case'"}, {"'Speakers'"}, 0.38, 2.0)
# ({"'Speakers'"}, {"'Lab Top Case'"}, 0.1, 2.0)
# ({"'Lab Top Case'"}, {"['Lab Top'"}, 0.38, 2.0)
# ({"['Lab Top'"}, {"'Lab Top Case'"}, 0.08, 2.0)
# ({"['Digital Camera'"}, {"'Speakers']"}, 0.14, 2.0)
# ({"'Speakers']"}, {"['Digital Camera'"}, 0.08, 2.0)
# ({"'Anti-Virus']"}, {"'Flash Drive'"}, 0.08, 2.0)
# ({"'Flash Drive'"}, {"'Anti-Virus']"}, 0.36, 2.0)
# ({"'Anti-Virus'"}, {"'Flash Drive'"}, 0.24, 2.0)
# ({"'Flash Drive'"}, {"'Anti-Virus'"}, 0.36, 2.0)
# ({"'Anti-Virus'"}, {"'Lab Top Case'"}, 0.24, 2.0)
# ({"'Lab Top Case'"}, {"'Anti-Virus'"}, 0.38, 2.0)
# ({"'Anti-Virus'"}, {"['Digital Camera'"}, 0.24, 2.0)
# ({"['Digital Camera'"}, {"'Anti-Virus'"}, 0.14, 2.0)
# ({"'Lab Top Case'"}, {"'Speakers']"}, 0.38, 2.0)
# ({"'Speakers']"}, {"'Lab Top Case'"}, 0.08, 2.0)
# ({"['Digital Camera'"}, {"'Lab Top'"}, 0.14, 2.0)
# ({"'Lab Top'"}, {"['Digital Camera'"}, 0.04, 2.0)
# ({"'Microsoft Office'"}, {"'Printer'"}, 0.28, 2.0)
# ({"'Printer'"}, {"'Microsoft Office'"}, 0.2, 2.0)
# ({"'Lab Top Case'"}, {"'Printer'"}, 0.38, 2.0)
# ({"'Printer'"}, {"'Lab Top Case'"}, 0.2, 2.0)
# ({"'Speakers'"}, {"'Flash Drive'"}, 0.1, 2.0)
# ({"'Flash Drive'"}, {"'Speakers'"}, 0.36, 2.0)
# ({"'Anti-Virus'"}, {"'Microsoft Office'"}, 0.24, 2.0)
# ({"'Microsoft Office'"}, {"'Anti-Virus'"}, 0.28, 2.0)
# ({"'Lab Top Case'"}, {"'External Hard Drive'"}, 0.38, 2.0)
# ({"'External Hard Drive'"}, {"'Lab Top Case'"}, 0.06, 2.0)
# ({"'Microsoft Office'"}, {"'Flash Drive'"}, 0.28, 2.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'"}, 0.36, 2.0)
# ({"'Flash Drive'"}, {"['Lab Top'"}, 0.36, 2.0)
# ({"['Lab Top'"}, {"'Flash Drive'"}, 0.08, 2.0)
# ({"['Digital Camera'"}, {"'Lab Top Case'"}, 0.14, 2.0)
# ({"'Lab Top Case'"}, {"['Digital Camera'"}, 0.38, 2.0)
# ({"'Printer'"}, {"'Flash Drive'"}, 0.2, 2.0)
# ({"'Flash Drive'"}, {"'Printer'"}, 0.36, 2.0)
# ({"['Digital Camera'"}, {"'Lab Top Case'", "'Speakers']"}, 0.14, 3.0)
# ({"'Lab Top Case'"}, {"['Digital Camera'", "'Speakers']"}, 0.38, 3.0)
# ({"'Speakers']"}, {"['Digital Camera'", "'Lab Top Case'"}, 0.08, 3.0)
# ({"['Digital Camera'", "'Lab Top Case'"}, {"'Speakers']"}, 0.04, 1.5)
# ({"['Digital Camera'", "'Speakers']"}, {"'Lab Top Case'"}, 0.04, 1.5)
# ({"'Lab Top Case'", "'Speakers']"}, {"['Digital Camera'"}, 0.04, 1.5)
# ({"'Anti-Virus'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.24, 3.0)
# ({"'Microsoft Office'"}, {"'Anti-Virus'", "'Flash Drive'"}, 0.28, 3.0)
# ({"'Flash Drive'"}, {"'Anti-Virus'", "'Microsoft Office'"}, 0.36, 3.0)
# ({"'Anti-Virus'", "'Microsoft Office'"}, {"'Flash Drive'"}, 0.08, 1.5)
# ({"'Anti-Virus'", "'Flash Drive'"}, {"'Microsoft Office'"}, 0.1, 1.5)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Anti-Virus'"}, 0.14, 1.5)
# ({"'Lab Top Case'"}, {"'Printer'", "'Flash Drive'"}, 0.38, 3.0)
# ({"'Printer'"}, {"'Lab Top Case'", "'Flash Drive'"}, 0.2, 3.0)
# ({"'Flash Drive'"}, {"'Lab Top Case'", "'Printer'"}, 0.36, 3.0)
# ({"'Lab Top Case'", "'Printer'"}, {"'Flash Drive'"}, 0.08, 1.5)
# ({"'Lab Top Case'", "'Flash Drive'"}, {"'Printer'"}, 0.12, 1.5)
# ({"'Printer'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.1, 1.5)
# ({"'Anti-Virus'"}, {"'Lab Top Case'", "'Flash Drive'"}, 0.24, 3.0)
# ({"'Lab Top Case'"}, {"'Anti-Virus'", "'Flash Drive'"}, 0.38, 3.0)
# ({"'Flash Drive'"}, {"'Anti-Virus'", "'Lab Top Case'"}, 0.36, 3.0)
# ({"'Anti-Virus'", "'Lab Top Case'"}, {"'Flash Drive'"}, 0.08, 1.5)
# ({"'Anti-Virus'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.1, 1.5)
# ({"'Lab Top Case'", "'Flash Drive'"}, {"'Anti-Virus'"}, 0.12, 1.5)
# ({"'Microsoft Office'"}, {"'Printer'", "'Flash Drive'"}, 0.28, 3.0)
# ({"'Printer'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.2, 3.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'", "'Printer'"}, 0.36, 3.0)
# ({"'Microsoft Office'", "'Printer'"}, {"'Flash Drive'"}, 0.08, 1.5)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Printer'"}, 0.14, 1.5)
# ({"'Printer'", "'Flash Drive'"}, {"'Microsoft Office'"}, 0.1, 1.5)
# ({"'Lab Top Case'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.38, 3.0)
# ({"'Microsoft Office'"}, {"'Lab Top Case'", "'Flash Drive'"}, 0.28, 3.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'", "'Lab Top Case'"}, 0.36, 3.0)
# ({"'Microsoft Office'", "'Lab Top Case'"}, {"'Flash Drive'"}, 0.12, 1.5)
# ({"'Lab Top Case'", "'Flash Drive'"}, {"'Microsoft Office'"}, 0.12, 1.5)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.14, 1.5)
# ({"'Anti-Virus'"}, {"'Microsoft Office'", "'Lab Top Case'"}, 0.24, 3.0)
# ({"'Lab Top Case'"}, {"'Anti-Virus'", "'Microsoft Office'"}, 0.38, 3.0)
# ({"'Microsoft Office'"}, {"'Anti-Virus'", "'Lab Top Case'"}, 0.28, 3.0)
# ({"'Anti-Virus'", "'Lab Top Case'"}, {"'Microsoft Office'"}, 0.08, 1.5)
# ({"'Anti-Virus'", "'Microsoft Office'"}, {"'Lab Top Case'"}, 0.08, 1.5)
# ({"'Microsoft Office'", "'Lab Top Case'"}, {"'Anti-Virus'"}, 0.12, 1.5)
# ({"'Microsoft Office'"}, {"'Lab Top Case'", "'Printer'"}, 0.28, 3.0)
# ({"'Lab Top Case'"}, {"'Microsoft Office'", "'Printer'"}, 0.38, 3.0)
# ({"'Printer'"}, {"'Lab Top Case'", "'Microsoft Office'"}, 0.2, 3.0)
# ({"'Lab Top Case'", "'Microsoft Office'"}, {"'Printer'"}, 0.12, 1.5)
# ({"'Microsoft Office'", "'Printer'"}, {"'Lab Top Case'"}, 0.08, 1.5)
# ({"'Lab Top Case'", "'Printer'"}, {"'Microsoft Office'"}, 0.08, 1.5)
# ({"'Anti-Virus'"}, {"'Printer'", "'Flash Drive'"}, 0.24, 3.0)
# ({"'Printer'"}, {"'Anti-Virus'", "'Flash Drive'"}, 0.2, 3.0)
# ({"'Flash Drive'"}, {"'Anti-Virus'", "'Printer'"}, 0.36, 3.0)
# ({"'Anti-Virus'", "'Printer'"}, {"'Flash Drive'"}, 0.04, 1.5)
# ({"'Anti-Virus'", "'Flash Drive'"}, {"'Printer'"}, 0.1, 1.5)
# ({"'Printer'", "'Flash Drive'"}, {"'Anti-Virus'"}, 0.1, 1.5)
# ({"'Microsoft Office'"}, {"'Speakers'", "'Flash Drive'"}, 0.28, 3.0)
# ({"'Speakers'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.1, 3.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'", "'Speakers'"}, 0.36, 3.0)
# ({"'Microsoft Office'", "'Speakers'"}, {"'Flash Drive'"}, 0.04, 1.5)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Speakers'"}, 0.14, 1.5)
# ({"'Speakers'", "'Flash Drive'"}, {"'Microsoft Office'"}, 0.04, 1.5)
# ({"'Anti-Virus'"}, {"'Microsoft Office'", "'Lab Top Case'", "'Flash Drive'"}, 0.24, 4.0)
# ({"'Lab Top Case'"}, {"'Anti-Virus'", "'Microsoft Office'", "'Flash Drive'"}, 0.38, 4.0)
# ({"'Microsoft Office'"}, {"'Anti-Virus'", "'Lab Top Case'", "'Flash Drive'"}, 0.28, 4.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'", "'Anti-Virus'", "'Lab Top Case'"}, 0.36, 4.0)
# ({"'Anti-Virus'", "'Lab Top Case'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.08, 2.0)
# ({"'Anti-Virus'", "'Microsoft Office'"}, {"'Lab Top Case'", "'Flash Drive'"}, 0.08, 2.0)
# ({"'Anti-Virus'", "'Flash Drive'"}, {"'Microsoft Office'", "'Lab Top Case'"}, 0.1, 2.0)
# ({"'Microsoft Office'", "'Lab Top Case'"}, {"'Anti-Virus'", "'Flash Drive'"}, 0.12, 2.0)
# ({"'Lab Top Case'", "'Flash Drive'"}, {"'Anti-Virus'", "'Microsoft Office'"}, 0.12, 2.0)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Anti-Virus'", "'Lab Top Case'"}, 0.14, 2.0)
# ({"'Microsoft Office'", "'Anti-Virus'", "'Lab Top Case'"}, {"'Flash Drive'"}, 0.04, 1.3333333333333333)
# ({"'Anti-Virus'", "'Lab Top Case'", "'Flash Drive'"}, {"'Microsoft Office'"}, 0.04, 1.3333333333333333)
# ({"'Anti-Virus'", "'Microsoft Office'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.04, 1.3333333333333333)
# ({"'Microsoft Office'", "'Lab Top Case'", "'Flash Drive'"}, {"'Anti-Virus'"}, 0.06, 1.3333333333333333)
# ({"'Microsoft Office'"}, {"'Lab Top Case'", "'Printer'", "'Flash Drive'"}, 0.28, 4.0)
# ({"'Lab Top Case'"}, {"'Microsoft Office'", "'Printer'", "'Flash Drive'"}, 0.38, 4.0)
# ({"'Printer'"}, {"'Lab Top Case'", "'Microsoft Office'", "'Flash Drive'"}, 0.2, 4.0)
# ({"'Flash Drive'"}, {"'Lab Top Case'", "'Microsoft Office'", "'Printer'"}, 0.36, 4.0)
# ({"'Lab Top Case'", "'Microsoft Office'"}, {"'Printer'", "'Flash Drive'"}, 0.12, 2.0)
# ({"'Microsoft Office'", "'Printer'"}, {"'Lab Top Case'", "'Flash Drive'"}, 0.08, 2.0)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Lab Top Case'", "'Printer'"}, 0.14, 2.0)
# ({"'Lab Top Case'", "'Printer'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.08, 2.0)
# ({"'Lab Top Case'", "'Flash Drive'"}, {"'Microsoft Office'", "'Printer'"}, 0.12, 2.0)
# ({"'Printer'", "'Flash Drive'"}, {"'Lab Top Case'", "'Microsoft Office'"}, 0.1, 2.0)
# ({"'Lab Top Case'", "'Microsoft Office'", "'Printer'"}, {"'Flash Drive'"}, 0.04, 1.3333333333333333)
# ({"'Lab Top Case'", "'Microsoft Office'", "'Flash Drive'"}, {"'Printer'"}, 0.06, 1.3333333333333333)
# ({"'Microsoft Office'", "'Printer'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.04, 1.3333333333333333)
# ({"'Lab Top Case'", "'Printer'", "'Flash Drive'"}, {"'Microsoft Office'"}, 0.04, 1.3333333333333333)
#
# K-mart Frequent Itemsets:
# {"['Decorative Pillows'"}
# {"'Shams'"}
# {"'Kids Bedding'"}
# {"'Bed Skirts'"}
# {"'Bedspreads'"}
# {"'Sheets']"}
# {"'Sheets'"}
# {"'Kids Bedding']"}
# {"'Kids Bedding'", "'Shams'"}
# {"'Bedspreads'", "'Shams'"}
# {"'Kids Bedding'", "'Sheets']"}
# {"'Bed Skirts'", "'Sheets']"}
# {"'Bed Skirts'", "'Shams'"}
# {"'Kids Bedding'", "'Bed Skirts'"}
# {"'Bed Skirts'", "'Bedspreads'"}
# {"'Bedspreads'", "'Bed Skirts'", "'Shams'"}
# {"'Kids Bedding'", "'Sheets']", "'Bed Skirts'"}
#
# K-mart Association Rules:
# ({"'Kids Bedding'"}, {"'Shams'"}, 0.29411764705882354, 2.0)
# ({"'Shams'"}, {"'Kids Bedding'"}, 0.29411764705882354, 2.0)
# ({"'Bedspreads'"}, {"'Shams'"}, 0.23529411764705882, 2.0)
# ({"'Shams'"}, {"'Bedspreads'"}, 0.29411764705882354, 2.0)
# ({"'Kids Bedding'"}, {"'Sheets']"}, 0.29411764705882354, 2.0)
# ({"'Sheets']"}, {"'Kids Bedding'"}, 0.23529411764705882, 2.0)
# ({"'Bed Skirts'"}, {"'Sheets']"}, 0.4117647058823529, 2.0)
# ({"'Sheets']"}, {"'Bed Skirts'"}, 0.23529411764705882, 2.0)
# ({"'Bed Skirts'"}, {"'Shams'"}, 0.4117647058823529, 2.0)
# ({"'Shams'"}, {"'Bed Skirts'"}, 0.29411764705882354, 2.0)
# ({"'Kids Bedding'"}, {"'Bed Skirts'"}, 0.29411764705882354, 2.0)
# ({"'Bed Skirts'"}, {"'Kids Bedding'"}, 0.4117647058823529, 2.0)
# ({"'Bed Skirts'"}, {"'Bedspreads'"}, 0.4117647058823529, 2.0)
# ({"'Bedspreads'"}, {"'Bed Skirts'"}, 0.23529411764705882, 2.0)
# ({"'Bedspreads'"}, {"'Bed Skirts'", "'Shams'"}, 0.23529411764705882, 3.0)
# ({"'Bed Skirts'"}, {"'Shams'", "'Bedspreads'"}, 0.4117647058823529, 3.0)
# ({"'Shams'"}, {"'Bed Skirts'", "'Bedspreads'"}, 0.29411764705882354, 3.0)
# ({"'Bed Skirts'", "'Bedspreads'"}, {"'Shams'"}, 0.11764705882352941, 1.5)
# ({"'Shams'", "'Bedspreads'"}, {"'Bed Skirts'"}, 0.11764705882352941, 1.5)
# ({"'Bed Skirts'", "'Shams'"}, {"'Bedspreads'"}, 0.11764705882352941, 1.5)
# ({"'Kids Bedding'"}, {"'Bed Skirts'", "'Sheets']"}, 0.29411764705882354, 3.0)
# ({"'Sheets']"}, {"'Kids Bedding'", "'Bed Skirts'"}, 0.23529411764705882, 3.0)
# ({"'Bed Skirts'"}, {"'Kids Bedding'", "'Sheets']"}, 0.4117647058823529, 3.0)
# ({"'Kids Bedding'", "'Sheets']"}, {"'Bed Skirts'"}, 0.11764705882352941, 1.5)
# ({"'Kids Bedding'", "'Bed Skirts'"}, {"'Sheets']"}, 0.11764705882352941, 1.5)
# ({"'Bed Skirts'", "'Sheets']"}, {"'Kids Bedding'"}, 0.11764705882352941, 1.5)
#
# Nike Frequent Itemsets:
# {"['Running Shoe'"}
# {"'Socks'"}
# {"'Sweatshirts'"}
# {"'Modern Pants'"}
# {"'Tech Pants'"}
# {"'Rash Guard'"}
# {"['Swimming Shirt'"}
# {"'Dry Fit V-Nick'"}
# {"'Hoodies'"}
# {"'Dry Fit V-Nick']"}
# {"'Swimming Shirt'"}
# {"'Soccer Shoe'"}
# {"'Swimming Shirt'", "'Sweatshirts'"}
# {"'Rash Guard'", "'Socks'"}
# {"'Swimming Shirt'", "['Running Shoe'"}
# {"'Hoodies'", "'Rash Guard'"}
# {"'Modern Pants'", "'Swimming Shirt'"}
# {"'Tech Pants'", "'Socks'"}
# {"'Sweatshirts'", "'Tech Pants'"}
# {"'Tech Pants'", "['Running Shoe'"}
# {"'Tech Pants'", "'Hoodies'"}
# {"'Modern Pants'", "'Tech Pants'"}
# {"'Dry Fit V-Nick']", "'Rash Guard'"}
# {"'Hoodies'", "'Soccer Shoe'"}
# {"'Sweatshirts'", "'Soccer Shoe'"}
# {"'Swimming Shirt'", "'Rash Guard'"}
# {"'Modern Pants'", "'Soccer Shoe'"}
# {"'Dry Fit V-Nick']", "'Tech Pants'"}
# {"'Swimming Shirt'", "'Tech Pants'"}
# {"'Tech Pants'", "'Soccer Shoe'"}
# {"'Socks'", "['Running Shoe'"}
# {"'Tech Pants'", "'Rash Guard'"}
# {"'Sweatshirts'", "'Socks'"}
# {"'Sweatshirts'", "['Running Shoe'"}
# {"'Dry Fit V-Nick']", "'Hoodies'"}
# {"'Sweatshirts'", "'Rash Guard'"}
# {"'Soccer Shoe'", "'Rash Guard'"}
# {"'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Socks'"}
# {"'Modern Pants'", "'Rash Guard'"}
# {"'Modern Pants'", "'Sweatshirts'"}
# {"'Modern Pants'", "['Running Shoe'"}
# {"'Swimming Shirt'", "'Socks'"}
# {"'Sweatshirts'", "'Tech Pants'", "['Running Shoe'"}
# {"'Tech Pants'", "'Rash Guard'", "'Soccer Shoe'"}
# {"'Sweatshirts'", "'Rash Guard'", "'Socks'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'"}
# {"'Modern Pants'", "'Rash Guard'", "'Socks'"}
# {"'Sweatshirts'", "'Tech Pants'", "'Rash Guard'"}
# {"'Socks'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Soccer Shoe'"}
# {"'Dry Fit V-Nick']", "'Tech Pants'", "'Rash Guard'"}
# {"'Swimming Shirt'", "'Sweatshirts'", "'Socks'"}
# {"'Modern Pants'", "'Swimming Shirt'", "'Socks'"}
# {"'Swimming Shirt'", "'Socks'", "['Running Shoe'"}
# {"'Modern Pants'", "'Soccer Shoe'", "'Rash Guard'"}
# {"'Sweatshirts'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Rash Guard'"}
# {"'Tech Pants'", "'Rash Guard'", "'Socks'"}
# {"'Swimming Shirt'", "'Sweatshirts'", "['Running Shoe'"}
# {"'Sweatshirts'", "'Tech Pants'", "'Soccer Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Swimming Shirt'"}
# {"'Modern Pants'", "'Swimming Shirt'", "['Running Shoe'"}
# {"'Modern Pants'", "'Swimming Shirt'", "'Rash Guard'"}
# {"'Tech Pants'", "'Soccer Shoe'", "'Hoodies'"}
# {"'Dry Fit V-Nick']", "'Tech Pants'", "'Hoodies'"}
# {"'Modern Pants'", "'Tech Pants'", "['Running Shoe'"}
# {"'Tech Pants'", "'Rash Guard'", "['Running Shoe'"}
# {"'Swimming Shirt'", "'Rash Guard'", "'Socks'"}
# {"'Swimming Shirt'", "'Tech Pants'", "['Running Shoe'"}
# {"'Sweatshirts'", "'Socks'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Socks'"}
# {"'Swimming Shirt'", "'Sweatshirts'", "'Rash Guard'"}
# {"'Modern Pants'", "'Socks'", "['Running Shoe'"}
# {"'Modern Pants'", "'Rash Guard'", "['Running Shoe'"}
# {"'Tech Pants'", "'Rash Guard'", "'Hoodies'"}
# {"'Modern Pants'", "'Tech Pants'", "'Soccer Shoe'"}
# {"'Sweatshirts'", "'Soccer Shoe'", "'Rash Guard'"}
# {"'Modern Pants'", "'Sweatshirts'", "['Running Shoe'"}
# {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'"}
# {"'Dry Fit V-Nick']", "'Hoodies'", "'Rash Guard'"}
# {"'Swimming Shirt'", "'Rash Guard'", "['Running Shoe'"}
# {"'Sweatshirts'", "'Tech Pants'", "'Socks'"}
# {"'Modern Pants'", "'Tech Pants'", "'Socks'"}
# {"'Tech Pants'", "'Socks'", "['Running Shoe'"}
# {"'Swimming Shirt'", "'Tech Pants'", "'Rash Guard'"}
# {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'", "'Socks'"}
# {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'", "'Soccer Shoe'"}
# {"'Modern Pants'", "'Tech Pants'", "'Socks'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Soccer Shoe'", "'Rash Guard'"}
# {"'Swimming Shirt'", "'Sweatshirts'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Rash Guard'", "['Running Shoe'"}
# {"'Sweatshirts'", "'Tech Pants'", "'Socks'", "['Running Shoe'"}
# {"'Swimming Shirt'", "'Sweatshirts'", "'Rash Guard'", "'Socks'"}
# {"'Sweatshirts'", "'Tech Pants'", "'Rash Guard'", "['Running Shoe'"}
# {"'Swimming Shirt'", "'Sweatshirts'", "'Socks'", "['Running Shoe'"}
# {"'Sweatshirts'", "'Tech Pants'", "'Rash Guard'", "'Soccer Shoe'"}
# {"'Sweatshirts'", "'Socks'", "'Rash Guard'", "['Running Shoe'"}
# {"'Sweatshirts'", "'Tech Pants'", "'Rash Guard'", "'Socks'"}
# {"'Modern Pants'", "'Swimming Shirt'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "['Running Shoe'"}
# {"'Swimming Shirt'", "'Socks'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Swimming Shirt'", "['Running Shoe'"}
# {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Soccer Shoe'"}
# {"'Tech Pants'", "'Socks'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Swimming Shirt'", "'Socks'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Rash Guard'", "'Socks'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Socks'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Rash Guard'", "'Swimming Shirt'"}
# {"'Dry Fit V-Nick']", "'Tech Pants'", "'Rash Guard'", "'Hoodies'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Rash Guard'"}
# {"'Modern Pants'", "'Swimming Shirt'", "'Socks'", "['Running Shoe'"}
# {"'Swimming Shirt'", "'Tech Pants'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Socks'"}
# {"'Modern Pants'", "'Socks'", "'Rash Guard'", "['Running Shoe'"}
# {"'Modern Pants'", "'Swimming Shirt'", "'Rash Guard'", "'Socks'"}
# {"'Tech Pants'", "['Running Shoe'", "'Sweatshirts'", "'Socks'", "'Rash Guard'"}
# {"'Tech Pants'", "'Sweatshirts'", "'Modern Pants'", "'Soccer Shoe'", "'Rash Guard'"}
# {"['Running Shoe'", "'Sweatshirts'", "'Socks'", "'Modern Pants'", "'Rash Guard'"}
# {"['Running Shoe'", "'Sweatshirts'", "'Swimming Shirt'", "'Socks'", "'Modern Pants'"}
# {"'Tech Pants'", "['Running Shoe'", "'Socks'", "'Modern Pants'", "'Rash Guard'"}
# {"['Running Shoe'", "'Swimming Shirt'", "'Socks'", "'Modern Pants'", "'Rash Guard'"}
# {"['Running Shoe'", "'Sweatshirts'", "'Swimming Shirt'", "'Modern Pants'", "'Rash Guard'"}
# {"'Tech Pants'", "'Sweatshirts'", "'Socks'", "'Modern Pants'", "'Rash Guard'"}
# {"'Tech Pants'", "['Running Shoe'", "'Sweatshirts'", "'Socks'", "'Modern Pants'"}
# {"'Tech Pants'", "['Running Shoe'", "'Sweatshirts'", "'Modern Pants'", "'Rash Guard'"}
# {"'Sweatshirts'", "'Swimming Shirt'", "'Socks'", "'Modern Pants'", "'Rash Guard'"}
# {"['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'", "'Socks'", "'Rash Guard'"}
# {"'Tech Pants'", "['Running Shoe'", "'Sweatshirts'", "'Socks'", "'Modern Pants'", "'Rash Guard'"}
# {"['Running Shoe'", "'Sweatshirts'", "'Swimming Shirt'", "'Socks'", "'Modern Pants'", "'Rash Guard'"}
#
# Nike Association Rules:
# ({"'Swimming Shirt'"}, {"'Sweatshirts'"}, 0.2748091603053435, 2.0)
# ({"'Sweatshirts'"}, {"'Swimming Shirt'"}, 0.42748091603053434, 2.0)
# ({"'Rash Guard'"}, {"'Socks'"}, 0.48854961832061067, 2.0)
# ({"'Socks'"}, {"'Rash Guard'"}, 0.366412213740458, 2.0)
# ({"'Swimming Shirt'"}, {"['Running Shoe'"}, 0.2748091603053435, 2.0)
# ({"['Running Shoe'"}, {"'Swimming Shirt'"}, 0.3816793893129771, 2.0)
# ({"'Hoodies'"}, {"'Rash Guard'"}, 0.07633587786259542, 2.0)
# ({"'Rash Guard'"}, {"'Hoodies'"}, 0.48854961832061067, 2.0)
# ({"'Modern Pants'"}, {"'Swimming Shirt'"}, 0.42748091603053434, 2.0)
# ({"'Swimming Shirt'"}, {"'Modern Pants'"}, 0.2748091603053435, 2.0)
# ({"'Tech Pants'"}, {"'Socks'"}, 0.3893129770992366, 2.0)
# ({"'Socks'"}, {"'Tech Pants'"}, 0.366412213740458, 2.0)
# ({"'Sweatshirts'"}, {"'Tech Pants'"}, 0.42748091603053434, 2.0)
# ({"'Tech Pants'"}, {"'Sweatshirts'"}, 0.3893129770992366, 2.0)
# ({"'Tech Pants'"}, {"['Running Shoe'"}, 0.3893129770992366, 2.0)
# ({"['Running Shoe'"}, {"'Tech Pants'"}, 0.3816793893129771, 2.0)
# ({"'Tech Pants'"}, {"'Hoodies'"}, 0.3893129770992366, 2.0)
# ({"'Hoodies'"}, {"'Tech Pants'"}, 0.07633587786259542, 2.0)
# ({"'Modern Pants'"}, {"'Tech Pants'"}, 0.42748091603053434, 2.0)
# ({"'Tech Pants'"}, {"'Modern Pants'"}, 0.3893129770992366, 2.0)
# ({"'Dry Fit V-Nick']"}, {"'Rash Guard'"}, 0.061068702290076333, 2.0)
# ({"'Rash Guard'"}, {"'Dry Fit V-Nick']"}, 0.48854961832061067, 2.0)
# ({"'Hoodies'"}, {"'Soccer Shoe'"}, 0.07633587786259542, 2.0)
# ({"'Soccer Shoe'"}, {"'Hoodies'"}, 0.13740458015267176, 2.0)
# ({"'Sweatshirts'"}, {"'Soccer Shoe'"}, 0.42748091603053434, 2.0)
# ({"'Soccer Shoe'"}, {"'Sweatshirts'"}, 0.13740458015267176, 2.0)
# ({"'Swimming Shirt'"}, {"'Rash Guard'"}, 0.2748091603053435, 2.0)
# ({"'Rash Guard'"}, {"'Swimming Shirt'"}, 0.48854961832061067, 2.0)
# ({"'Modern Pants'"}, {"'Soccer Shoe'"}, 0.42748091603053434, 2.0)
# ({"'Soccer Shoe'"}, {"'Modern Pants'"}, 0.13740458015267176, 2.0)
# ({"'Dry Fit V-Nick']"}, {"'Tech Pants'"}, 0.061068702290076333, 2.0)
# ({"'Tech Pants'"}, {"'Dry Fit V-Nick']"}, 0.3893129770992366, 2.0)
# ({"'Swimming Shirt'"}, {"'Tech Pants'"}, 0.2748091603053435, 2.0)
# ({"'Tech Pants'"}, {"'Swimming Shirt'"}, 0.3893129770992366, 2.0)
# ({"'Tech Pants'"}, {"'Soccer Shoe'"}, 0.3893129770992366, 2.0)
# ({"'Soccer Shoe'"}, {"'Tech Pants'"}, 0.13740458015267176, 2.0)
# ({"'Socks'"}, {"['Running Shoe'"}, 0.366412213740458, 2.0)
# ({"['Running Shoe'"}, {"'Socks'"}, 0.3816793893129771, 2.0)
# ({"'Tech Pants'"}, {"'Rash Guard'"}, 0.3893129770992366, 2.0)
# ({"'Rash Guard'"}, {"'Tech Pants'"}, 0.48854961832061067, 2.0)
# ({"'Sweatshirts'"}, {"'Socks'"}, 0.42748091603053434, 2.0)
# ({"'Socks'"}, {"'Sweatshirts'"}, 0.366412213740458, 2.0)
# ({"'Sweatshirts'"}, {"['Running Shoe'"}, 0.42748091603053434, 2.0)
# ({"['Running Shoe'"}, {"'Sweatshirts'"}, 0.3816793893129771, 2.0)
# ({"'Dry Fit V-Nick']"}, {"'Hoodies'"}, 0.061068702290076333, 2.0)
# ({"'Hoodies'"}, {"'Dry Fit V-Nick']"}, 0.07633587786259542, 2.0)
# ({"'Sweatshirts'"}, {"'Rash Guard'"}, 0.42748091603053434, 2.0)
# ({"'Rash Guard'"}, {"'Sweatshirts'"}, 0.48854961832061067, 2.0)
# ({"'Soccer Shoe'"}, {"'Rash Guard'"}, 0.13740458015267176, 2.0)
# ({"'Rash Guard'"}, {"'Soccer Shoe'"}, 0.48854961832061067, 2.0)
# ({"'Rash Guard'"}, {"['Running Shoe'"}, 0.48854961832061067, 2.0)
# ({"['Running Shoe'"}, {"'Rash Guard'"}, 0.3816793893129771, 2.0)
# ({"'Modern Pants'"}, {"'Socks'"}, 0.42748091603053434, 2.0)
# ({"'Socks'"}, {"'Modern Pants'"}, 0.366412213740458, 2.0)
# ({"'Modern Pants'"}, {"'Rash Guard'"}, 0.42748091603053434, 2.0)
# ({"'Rash Guard'"}, {"'Modern Pants'"}, 0.48854961832061067, 2.0)
# ({"'Modern Pants'"}, {"'Sweatshirts'"}, 0.42748091603053434, 2.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'"}, 0.42748091603053434, 2.0)
# ({"'Modern Pants'"}, {"['Running Shoe'"}, 0.42748091603053434, 2.0)
# ({"['Running Shoe'"}, {"'Modern Pants'"}, 0.3816793893129771, 2.0)
# ({"'Swimming Shirt'"}, {"'Socks'"}, 0.2748091603053435, 2.0)
# ({"'Socks'"}, {"'Swimming Shirt'"}, 0.366412213740458, 2.0)
# ({"'Sweatshirts'"}, {"'Tech Pants'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Tech Pants'"}, {"'Sweatshirts'", "['Running Shoe'"}, 0.3893129770992366, 3.0)
# ({"['Running Shoe'"}, {"'Sweatshirts'", "'Tech Pants'"}, 0.3816793893129771, 3.0)
# ({"'Sweatshirts'", "'Tech Pants'"}, {"['Running Shoe'"}, 0.15267175572519084, 1.5)
# ({"'Sweatshirts'", "['Running Shoe'"}, {"'Tech Pants'"}, 0.183206106870229, 1.5)
# ({"'Tech Pants'", "['Running Shoe'"}, {"'Sweatshirts'"}, 0.13740458015267176, 1.5)
# ({"'Tech Pants'"}, {"'Soccer Shoe'", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Tech Pants'", "'Soccer Shoe'"}, 0.48854961832061067, 3.0)
# ({"'Soccer Shoe'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.13740458015267176, 3.0)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Soccer Shoe'"}, 0.19083969465648856, 1.5)
# ({"'Tech Pants'", "'Soccer Shoe'"}, {"'Rash Guard'"}, 0.06870229007633588, 1.5)
# ({"'Soccer Shoe'", "'Rash Guard'"}, {"'Tech Pants'"}, 0.061068702290076333, 1.5)
# ({"'Sweatshirts'"}, {"'Rash Guard'", "'Socks'"}, 0.42748091603053434, 3.0)
# ({"'Rash Guard'"}, {"'Sweatshirts'", "'Socks'"}, 0.48854961832061067, 3.0)
# ({"'Socks'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.366412213740458, 3.0)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"'Socks'"}, 0.21374045801526717, 1.5)
# ({"'Sweatshirts'", "'Socks'"}, {"'Rash Guard'"}, 0.183206106870229, 1.5)
# ({"'Rash Guard'", "'Socks'"}, {"'Sweatshirts'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'"}, {"'Sweatshirts'", "'Tech Pants'"}, 0.42748091603053434, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Tech Pants'"}, 0.42748091603053434, 3.0)
# ({"'Tech Pants'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.3893129770992366, 3.0)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Tech Pants'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'", "'Tech Pants'"}, {"'Sweatshirts'"}, 0.15267175572519084, 1.5)
# ({"'Sweatshirts'", "'Tech Pants'"}, {"'Modern Pants'"}, 0.15267175572519084, 1.5)
# ({"'Modern Pants'"}, {"'Rash Guard'", "'Socks'"}, 0.42748091603053434, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Socks'"}, 0.48854961832061067, 3.0)
# ({"'Socks'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.366412213740458, 3.0)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Socks'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'", "'Socks'"}, {"'Rash Guard'"}, 0.183206106870229, 1.5)
# ({"'Rash Guard'", "'Socks'"}, {"'Modern Pants'"}, 0.183206106870229, 1.5)
# ({"'Sweatshirts'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Tech Pants'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Sweatshirts'", "'Tech Pants'"}, 0.48854961832061067, 3.0)
# ({"'Sweatshirts'", "'Tech Pants'"}, {"'Rash Guard'"}, 0.15267175572519084, 1.5)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"'Tech Pants'"}, 0.21374045801526717, 1.5)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.19083969465648856, 1.5)
# ({"'Socks'"}, {"'Rash Guard'", "['Running Shoe'"}, 0.366412213740458, 3.0)
# ({"'Rash Guard'"}, {"['Running Shoe'", "'Socks'"}, 0.48854961832061067, 3.0)
# ({"['Running Shoe'"}, {"'Rash Guard'", "'Socks'"}, 0.3816793893129771, 3.0)
# ({"'Rash Guard'", "'Socks'"}, {"['Running Shoe'"}, 0.183206106870229, 1.5)
# ({"['Running Shoe'", "'Socks'"}, {"'Rash Guard'"}, 0.183206106870229, 1.5)
# ({"'Rash Guard'", "['Running Shoe'"}, {"'Socks'"}, 0.19083969465648856, 1.5)
# ({"'Modern Pants'"}, {"'Sweatshirts'", "'Soccer Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Soccer Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Soccer Shoe'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.13740458015267176, 3.0)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Soccer Shoe'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'", "'Soccer Shoe'"}, {"'Sweatshirts'"}, 0.061068702290076333, 1.5)
# ({"'Sweatshirts'", "'Soccer Shoe'"}, {"'Modern Pants'"}, 0.061068702290076333, 1.5)
# ({"'Dry Fit V-Nick']"}, {"'Tech Pants'", "'Rash Guard'"}, 0.061068702290076333, 3.0)
# ({"'Tech Pants'"}, {"'Dry Fit V-Nick']", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Dry Fit V-Nick']", "'Tech Pants'"}, 0.48854961832061067, 3.0)
# ({"'Dry Fit V-Nick']", "'Tech Pants'"}, {"'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Dry Fit V-Nick']", "'Rash Guard'"}, {"'Tech Pants'"}, 0.030534351145038167, 1.5)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Dry Fit V-Nick']"}, 0.19083969465648856, 1.5)
# ({"'Swimming Shirt'"}, {"'Sweatshirts'", "'Socks'"}, 0.2748091603053435, 3.0)
# ({"'Sweatshirts'"}, {"'Swimming Shirt'", "'Socks'"}, 0.42748091603053434, 3.0)
# ({"'Socks'"}, {"'Swimming Shirt'", "'Sweatshirts'"}, 0.366412213740458, 3.0)
# ({"'Swimming Shirt'", "'Sweatshirts'"}, {"'Socks'"}, 0.12213740458015267, 1.5)
# ({"'Swimming Shirt'", "'Socks'"}, {"'Sweatshirts'"}, 0.12213740458015267, 1.5)
# ({"'Sweatshirts'", "'Socks'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'"}, {"'Swimming Shirt'", "'Socks'"}, 0.42748091603053434, 3.0)
# ({"'Swimming Shirt'"}, {"'Modern Pants'", "'Socks'"}, 0.2748091603053435, 3.0)
# ({"'Socks'"}, {"'Modern Pants'", "'Swimming Shirt'"}, 0.366412213740458, 3.0)
# ({"'Modern Pants'", "'Swimming Shirt'"}, {"'Socks'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'", "'Socks'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Swimming Shirt'", "'Socks'"}, {"'Modern Pants'"}, 0.12213740458015267, 1.5)
# ({"'Swimming Shirt'"}, {"['Running Shoe'", "'Socks'"}, 0.2748091603053435, 3.0)
# ({"'Socks'"}, {"'Swimming Shirt'", "['Running Shoe'"}, 0.366412213740458, 3.0)
# ({"['Running Shoe'"}, {"'Swimming Shirt'", "'Socks'"}, 0.3816793893129771, 3.0)
# ({"'Swimming Shirt'", "'Socks'"}, {"['Running Shoe'"}, 0.12213740458015267, 1.5)
# ({"'Swimming Shirt'", "['Running Shoe'"}, {"'Socks'"}, 0.13740458015267176, 1.5)
# ({"['Running Shoe'", "'Socks'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'"}, {"'Soccer Shoe'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Soccer Shoe'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.13740458015267176, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Soccer Shoe'"}, 0.48854961832061067, 3.0)
# ({"'Modern Pants'", "'Soccer Shoe'"}, {"'Rash Guard'"}, 0.061068702290076333, 1.5)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Soccer Shoe'"}, 0.21374045801526717, 1.5)
# ({"'Soccer Shoe'", "'Rash Guard'"}, {"'Modern Pants'"}, 0.061068702290076333, 1.5)
# ({"'Sweatshirts'"}, {"'Rash Guard'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Rash Guard'"}, {"'Sweatshirts'", "['Running Shoe'"}, 0.48854961832061067, 3.0)
# ({"['Running Shoe'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.3816793893129771, 3.0)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"['Running Shoe'"}, 0.21374045801526717, 1.5)
# ({"'Sweatshirts'", "['Running Shoe'"}, {"'Rash Guard'"}, 0.183206106870229, 1.5)
# ({"'Rash Guard'", "['Running Shoe'"}, {"'Sweatshirts'"}, 0.19083969465648856, 1.5)
# ({"'Modern Pants'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.48854961832061067, 3.0)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Rash Guard'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.21374045801526717, 1.5)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"'Modern Pants'"}, 0.21374045801526717, 1.5)
# ({"'Tech Pants'"}, {"'Rash Guard'", "'Socks'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Tech Pants'", "'Socks'"}, 0.48854961832061067, 3.0)
# ({"'Socks'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.366412213740458, 3.0)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Socks'"}, 0.19083969465648856, 1.5)
# ({"'Tech Pants'", "'Socks'"}, {"'Rash Guard'"}, 0.12213740458015267, 1.5)
# ({"'Rash Guard'", "'Socks'"}, {"'Tech Pants'"}, 0.183206106870229, 1.5)
# ({"'Swimming Shirt'"}, {"'Sweatshirts'", "['Running Shoe'"}, 0.2748091603053435, 3.0)
# ({"'Sweatshirts'"}, {"'Swimming Shirt'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"['Running Shoe'"}, {"'Swimming Shirt'", "'Sweatshirts'"}, 0.3816793893129771, 3.0)
# ({"'Swimming Shirt'", "'Sweatshirts'"}, {"['Running Shoe'"}, 0.12213740458015267, 1.5)
# ({"'Swimming Shirt'", "['Running Shoe'"}, {"'Sweatshirts'"}, 0.13740458015267176, 1.5)
# ({"'Sweatshirts'", "['Running Shoe'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Sweatshirts'"}, {"'Tech Pants'", "'Soccer Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Tech Pants'"}, {"'Sweatshirts'", "'Soccer Shoe'"}, 0.3893129770992366, 3.0)
# ({"'Soccer Shoe'"}, {"'Sweatshirts'", "'Tech Pants'"}, 0.13740458015267176, 3.0)
# ({"'Sweatshirts'", "'Tech Pants'"}, {"'Soccer Shoe'"}, 0.15267175572519084, 1.5)
# ({"'Sweatshirts'", "'Soccer Shoe'"}, {"'Tech Pants'"}, 0.061068702290076333, 1.5)
# ({"'Tech Pants'", "'Soccer Shoe'"}, {"'Sweatshirts'"}, 0.06870229007633588, 1.5)
# ({"'Modern Pants'"}, {"'Swimming Shirt'", "'Sweatshirts'"}, 0.42748091603053434, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Swimming Shirt'"}, 0.42748091603053434, 3.0)
# ({"'Swimming Shirt'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.2748091603053435, 3.0)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Swimming Shirt'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'", "'Swimming Shirt'"}, {"'Sweatshirts'"}, 0.12213740458015267, 1.5)
# ({"'Swimming Shirt'", "'Sweatshirts'"}, {"'Modern Pants'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'"}, {"'Swimming Shirt'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Swimming Shirt'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.2748091603053435, 3.0)
# ({"['Running Shoe'"}, {"'Modern Pants'", "'Swimming Shirt'"}, 0.3816793893129771, 3.0)
# ({"'Modern Pants'", "'Swimming Shirt'"}, {"['Running Shoe'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'", "['Running Shoe'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Swimming Shirt'", "['Running Shoe'"}, {"'Modern Pants'"}, 0.13740458015267176, 1.5)
# ({"'Modern Pants'"}, {"'Swimming Shirt'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Swimming Shirt'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.2748091603053435, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Swimming Shirt'"}, 0.48854961832061067, 3.0)
# ({"'Modern Pants'", "'Swimming Shirt'"}, {"'Rash Guard'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Swimming Shirt'"}, 0.21374045801526717, 1.5)
# ({"'Swimming Shirt'", "'Rash Guard'"}, {"'Modern Pants'"}, 0.13740458015267176, 1.5)
# ({"'Tech Pants'"}, {"'Soccer Shoe'", "'Hoodies'"}, 0.3893129770992366, 3.0)
# ({"'Soccer Shoe'"}, {"'Tech Pants'", "'Hoodies'"}, 0.13740458015267176, 3.0)
# ({"'Hoodies'"}, {"'Tech Pants'", "'Soccer Shoe'"}, 0.07633587786259542, 3.0)
# ({"'Tech Pants'", "'Soccer Shoe'"}, {"'Hoodies'"}, 0.06870229007633588, 1.5)
# ({"'Tech Pants'", "'Hoodies'"}, {"'Soccer Shoe'"}, 0.03816793893129771, 1.5)
# ({"'Soccer Shoe'", "'Hoodies'"}, {"'Tech Pants'"}, 0.015267175572519083, 1.5)
# ({"'Dry Fit V-Nick']"}, {"'Tech Pants'", "'Hoodies'"}, 0.061068702290076333, 3.0)
# ({"'Tech Pants'"}, {"'Dry Fit V-Nick']", "'Hoodies'"}, 0.3893129770992366, 3.0)
# ({"'Hoodies'"}, {"'Dry Fit V-Nick']", "'Tech Pants'"}, 0.07633587786259542, 3.0)
# ({"'Dry Fit V-Nick']", "'Tech Pants'"}, {"'Hoodies'"}, 0.030534351145038167, 1.5)
# ({"'Dry Fit V-Nick']", "'Hoodies'"}, {"'Tech Pants'"}, 0.030534351145038167, 1.5)
# ({"'Tech Pants'", "'Hoodies'"}, {"'Dry Fit V-Nick']"}, 0.03816793893129771, 1.5)
# ({"'Modern Pants'"}, {"'Tech Pants'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Tech Pants'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.3893129770992366, 3.0)
# ({"['Running Shoe'"}, {"'Modern Pants'", "'Tech Pants'"}, 0.3816793893129771, 3.0)
# ({"'Modern Pants'", "'Tech Pants'"}, {"['Running Shoe'"}, 0.15267175572519084, 1.5)
# ({"'Modern Pants'", "['Running Shoe'"}, {"'Tech Pants'"}, 0.183206106870229, 1.5)
# ({"'Tech Pants'", "['Running Shoe'"}, {"'Modern Pants'"}, 0.13740458015267176, 1.5)
# ({"'Tech Pants'"}, {"'Rash Guard'", "['Running Shoe'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Tech Pants'", "['Running Shoe'"}, 0.48854961832061067, 3.0)
# ({"['Running Shoe'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.3816793893129771, 3.0)
# ({"'Tech Pants'", "'Rash Guard'"}, {"['Running Shoe'"}, 0.19083969465648856, 1.5)
# ({"'Tech Pants'", "['Running Shoe'"}, {"'Rash Guard'"}, 0.13740458015267176, 1.5)
# ({"'Rash Guard'", "['Running Shoe'"}, {"'Tech Pants'"}, 0.19083969465648856, 1.5)
# ({"'Swimming Shirt'"}, {"'Rash Guard'", "'Socks'"}, 0.2748091603053435, 3.0)
# ({"'Rash Guard'"}, {"'Swimming Shirt'", "'Socks'"}, 0.48854961832061067, 3.0)
# ({"'Socks'"}, {"'Swimming Shirt'", "'Rash Guard'"}, 0.366412213740458, 3.0)
# ({"'Swimming Shirt'", "'Rash Guard'"}, {"'Socks'"}, 0.13740458015267176, 1.5)
# ({"'Swimming Shirt'", "'Socks'"}, {"'Rash Guard'"}, 0.12213740458015267, 1.5)
# ({"'Rash Guard'", "'Socks'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Swimming Shirt'"}, {"'Tech Pants'", "['Running Shoe'"}, 0.2748091603053435, 3.0)
# ({"'Tech Pants'"}, {"'Swimming Shirt'", "['Running Shoe'"}, 0.3893129770992366, 3.0)
# ({"['Running Shoe'"}, {"'Swimming Shirt'", "'Tech Pants'"}, 0.3816793893129771, 3.0)
# ({"'Swimming Shirt'", "'Tech Pants'"}, {"['Running Shoe'"}, 0.030534351145038167, 1.5)
# ({"'Swimming Shirt'", "['Running Shoe'"}, {"'Tech Pants'"}, 0.13740458015267176, 1.5)
# ({"'Tech Pants'", "['Running Shoe'"}, {"'Swimming Shirt'"}, 0.13740458015267176, 1.5)
# ({"'Sweatshirts'"}, {"['Running Shoe'", "'Socks'"}, 0.42748091603053434, 3.0)
# ({"'Socks'"}, {"'Sweatshirts'", "['Running Shoe'"}, 0.366412213740458, 3.0)
# ({"['Running Shoe'"}, {"'Sweatshirts'", "'Socks'"}, 0.3816793893129771, 3.0)
# ({"'Sweatshirts'", "'Socks'"}, {"['Running Shoe'"}, 0.183206106870229, 1.5)
# ({"'Sweatshirts'", "['Running Shoe'"}, {"'Socks'"}, 0.183206106870229, 1.5)
# ({"['Running Shoe'", "'Socks'"}, {"'Sweatshirts'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'"}, {"'Sweatshirts'", "'Socks'"}, 0.42748091603053434, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Socks'"}, 0.42748091603053434, 3.0)
# ({"'Socks'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.366412213740458, 3.0)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Socks'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'", "'Socks'"}, {"'Sweatshirts'"}, 0.183206106870229, 1.5)
# ({"'Sweatshirts'", "'Socks'"}, {"'Modern Pants'"}, 0.183206106870229, 1.5)
# ({"'Swimming Shirt'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.2748091603053435, 3.0)
# ({"'Sweatshirts'"}, {"'Swimming Shirt'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Rash Guard'"}, {"'Swimming Shirt'", "'Sweatshirts'"}, 0.48854961832061067, 3.0)
# ({"'Swimming Shirt'", "'Sweatshirts'"}, {"'Rash Guard'"}, 0.12213740458015267, 1.5)
# ({"'Swimming Shirt'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.13740458015267176, 1.5)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"'Swimming Shirt'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'"}, {"['Running Shoe'", "'Socks'"}, 0.42748091603053434, 3.0)
# ({"'Socks'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.366412213740458, 3.0)
# ({"['Running Shoe'"}, {"'Modern Pants'", "'Socks'"}, 0.3816793893129771, 3.0)
# ({"'Modern Pants'", "'Socks'"}, {"['Running Shoe'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'", "['Running Shoe'"}, {"'Socks'"}, 0.183206106870229, 1.5)
# ({"['Running Shoe'", "'Socks'"}, {"'Modern Pants'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'"}, {"'Rash Guard'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.48854961832061067, 3.0)
# ({"['Running Shoe'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.3816793893129771, 3.0)
# ({"'Modern Pants'", "'Rash Guard'"}, {"['Running Shoe'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'", "['Running Shoe'"}, {"'Rash Guard'"}, 0.183206106870229, 1.5)
# ({"'Rash Guard'", "['Running Shoe'"}, {"'Modern Pants'"}, 0.19083969465648856, 1.5)
# ({"'Tech Pants'"}, {"'Hoodies'", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Tech Pants'", "'Hoodies'"}, 0.48854961832061067, 3.0)
# ({"'Hoodies'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.07633587786259542, 3.0)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Hoodies'"}, 0.19083969465648856, 1.5)
# ...
#
#     leverage  conviction  zhangs_metric
# 0     0.0875        2.75       0.583333
# 1     0.1425        3.85       0.730769
# 2     0.1200        2.20       0.666667
# 3     0.1100         inf       0.687500
# 4     0.1000        3.00       0.666667
# 5     0.1300         inf       0.812500
# 6     0.1200         inf       0.750000
# 7     0.1100         inf       0.687500
# 8     0.1250        3.50       0.833333
# 9     0.1300         inf       0.812500
# 10    0.1100         inf       0.687500
# 11    0.1400         inf       0.875000
# FP-Growth:
#                      antecedents                     consequents  \
# 0                      ('Shams')                  ('Bed Skirts')
# 1               ('Kids Bedding')                  ('Bed Skirts')
# 2                 ('Bedspreads')                       ('Shams')
# 3                 ('Bedspreads')                  ('Bed Skirts')
# 4   ('Bed Skirts', 'Bedspreads')                       ('Shams')
# 5        ('Bedspreads', 'Shams')                  ('Bed Skirts')
# 6                 ('Bedspreads')         ('Bed Skirts', 'Shams')
# 7                    ('Sheets'])                ('Kids Bedding')
# 8                    ('Sheets'])                  ('Bed Skirts')
# 9    ('Kids Bedding', 'Sheets'])                  ('Bed Skirts')
# 10     ('Bed Skirts', 'Sheets'])                ('Kids Bedding')
# 11                   ('Sheets'])  ('Kids Bedding', 'Bed Skirts')
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                 0.40                0.45      0.3    0.750000  1.666667
# 1                 0.35                0.45      0.3    0.857143  1.904762
# 2                 0.25                0.40      0.2    0.800000  2.000000
# 3                 0.25                0.45      0.2    0.800000  1.777778
# 4                 0.20                0.40      0.2    1.000000  2.500000
# 5                 0.20                0.45      0.2    1.000000  2.222222
# 6                 0.25                0.30      0.2    0.800000  2.666667
# 7                 0.20                0.35      0.2    1.000000  2.857143
# 8                 0.20                0.45      0.2    1.000000  2.222222
# 9                 0.20                0.45      0.2    1.000000  2.222222
# 10                0.20                0.35      0.2    1.000000  2.857143
# 11                0.20                0.30      0.2    1.000000  3.333333
#
#     leverage  conviction  zhangs_metric
# 0     0.1200        2.20       0.666667
# 1     0.1425        3.85       0.730769
# 2     0.1000        3.00       0.666667
# 3     0.0875        2.75       0.583333
# 4     0.1200         inf       0.750000
# 5     0.1100         inf       0.687500
# 6     0.1250        3.50       0.833333
# 7     0.1300         inf       0.812500
# 8     0.1100         inf       0.687500
# 9     0.1100         inf       0.687500
# 10    0.1300         inf       0.812500
# 11    0.1400         inf       0.875000
#
# Nike Timing Performance:
# Brute-force Execution Time: 1.5868217945098877 seconds
# Apriori Execution Time: 0.040474891662597656 seconds
# FP-Growth Execution Time: 0.034084320068359375 seconds
#
# Nike Association Rules:
# Brute-force:
# [{"['Running Shoe'"}, {"'Socks'"}, {"'Sweatshirts'"}, {"'Modern Pants'"}, {"'Tech Pants'"}, {"'Rash Guard'"}, {"['Swimming Shirt'"}, {"'Dry Fit V-Nick'"}, {"'Hoodies'"}, {"'Dry Fit V-Nick']"}, {"'Swimming Shirt'"}, {"'Soccer Shoe'"}, {"'Swimming Shirt'", "'Sweatshirts'"}, {"'Rash Guard'", "'Socks'"}, {"'Swimming Shirt'", "['Running Shoe'"}, {"'Hoodies'", "'Rash Guard'"}, {"'Modern Pants'", "'Swimming Shirt'"}, {"'Tech Pants'", "'Socks'"}, {"'Sweatshirts'", "'Tech Pants'"}, {"'Tech Pants'", "['Running Shoe'"}, {"'Tech Pants'", "'Hoodies'"}, {"'Modern Pants'", "'Tech Pants'"}, {"'Dry Fit V-Nick']", "'Rash Guard'"}, {"'Hoodies'", "'Soccer Shoe'"}, {"'Sweatshirts'", "'Soccer Shoe'"}, {"'Swimming Shirt'", "'Rash Guard'"}, {"'Modern Pants'", "'Soccer Shoe'"}, {"'Dry Fit V-Nick']", "'Tech Pants'"}, {"'Swimming Shirt'", "'Tech Pants'"}, {"'Tech Pants'", "'Soccer Shoe'"}, {"'Socks'", "['Running Shoe'"}, {"'Tech Pants'", "'Rash Guard'"}, {"'Sweatshirts'", "'Socks'"}, {"'Sweatshirts'", "['Running Shoe'"}, {"'Dry Fit V-Nick']", "'Hoodies'"}, {"'Sweatshirts'", "'Rash Guard'"}, {"'Soccer Shoe'", "'Rash Guard'"}, {"'Rash Guard'", "['Running Shoe'"}, {"'Modern Pants'", "'Socks'"}, {"'Modern Pants'", "'Rash Guard'"}, {"'Modern Pants'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'"}, {"'Swimming Shirt'", "'Socks'"}, {"'Sweatshirts'", "'Tech Pants'", "['Running Shoe'"}, {"'Tech Pants'", "'Rash Guard'", "'Soccer Shoe'"}, {"'Sweatshirts'", "'Rash Guard'", "'Socks'"}, {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'"}, {"'Modern Pants'", "'Rash Guard'", "'Socks'"}, {"'Sweatshirts'", "'Tech Pants'", "'Rash Guard'"}, {"'Socks'", "'Rash Guard'", "['Running Shoe'"}, {"'Modern Pants'", "'Sweatshirts'", "'Soccer Shoe'"}, {"'Dry Fit V-Nick']", "'Tech Pants'", "'Rash Guard'"}, {"'Swimming Shirt'", "'Sweatshirts'", "'Socks'"}, {"'Modern Pants'", "'Swimming Shirt'", "'Socks'"}, {"'Swimming Shirt'", "'Socks'", "['Running Shoe'"}, {"'Modern Pants'", "'Soccer Shoe'", "'Rash Guard'"}, {"'Sweatshirts'", "'Rash Guard'", "['Running Shoe'"}, {"'Modern Pants'", "'Sweatshirts'", "'Rash Guard'"}, {"'Tech Pants'", "'Rash Guard'", "'Socks'"}, {"'Swimming Shirt'", "'Sweatshirts'", "['Running Shoe'"}, {"'Sweatshirts'", "'Tech Pants'", "'Soccer Shoe'"}, {"'Modern Pants'", "'Sweatshirts'", "'Swimming Shirt'"}, {"'Modern Pants'", "'Swimming Shirt'", "['Running Shoe'"}, {"'Modern Pants'", "'Swimming Shirt'", "'Rash Guard'"}, {"'Tech Pants'", "'Soccer Shoe'", "'Hoodies'"}, {"'Dry Fit V-Nick']", "'Tech Pants'", "'Hoodies'"}, {"'Modern Pants'", "'Tech Pants'", "['Running Shoe'"}, {"'Tech Pants'", "'Rash Guard'", "['Running Shoe'"}, {"'Swimming Shirt'", "'Rash Guard'", "'Socks'"}, {"'Swimming Shirt'", "'Tech Pants'", "['Running Shoe'"}, {"'Sweatshirts'", "'Socks'", "['Running Shoe'"}, {"'Modern Pants'", "'Sweatshirts'", "'Socks'"}, {"'Swimming Shirt'", "'Sweatshirts'", "'Rash Guard'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'"}, {"'Modern Pants'", "'Rash Guard'", "['Running Shoe'"}, {"'Tech Pants'", "'Rash Guard'", "'Hoodies'"}, {"'Modern Pants'", "'Tech Pants'", "'Soccer Shoe'"}, {"'Sweatshirts'", "'Soccer Shoe'", "'Rash Guard'"}, {"'Modern Pants'", "'Sweatshirts'", "['Running Shoe'"}, {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'"}, {"'Dry Fit V-Nick']", "'Hoodies'", "'Rash Guard'"}, {"'Swimming Shirt'", "'Rash Guard'", "['Running Shoe'"}, {"'Sweatshirts'", "'Tech Pants'", "'Socks'"}, {"'Modern Pants'", "'Tech Pants'", "'Socks'"}, {"'Tech Pants'", "'Socks'", "['Running Shoe'"}, {"'Swimming Shirt'", "'Tech Pants'", "'Rash Guard'"}, {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'", "'Socks'"}, {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'", "'Soccer Shoe'"}, {"'Modern Pants'", "'Tech Pants'", "'Socks'", "['Running Shoe'"}, {"'Modern Pants'", "'Sweatshirts'", "'Soccer Shoe'", "'Rash Guard'"}, {"'Swimming Shirt'", "'Sweatshirts'", "'Rash Guard'", "['Running Shoe'"}, {"'Modern Pants'", "'Sweatshirts'", "'Rash Guard'", "['Running Shoe'"}, {"'Sweatshirts'", "'Tec ...
# Apriori:
#                          antecedents  \
# 0                ('Dry Fit V-Nick'])
# 1                        ('Hoodies')
# 2                    ('Soccer Shoe')
# 3                        ('Hoodies')
# 4                     ('Tech Pants')
# ..                               ...
# 656  ('Tech Pants', ['Running Shoe')
# 657    ('Sweatshirts', 'Tech Pants')
# 658          ('Tech Pants', 'Socks')
# 659   ('Modern Pants', 'Tech Pants')
# 660          ('Rash Guard', 'Socks')
#
#                                            consequents  antecedent support  \
# 0                                       ('Rash Guard')                0.30
# 1                                       ('Rash Guard')                0.30
# 2                                          ('Hoodies')                0.25
# 3                                       ('Tech Pants')                0.30
# 4                                          ('Hoodies')                0.35
# ..                                                 ...                 ...
# 656  ('Modern Pants', 'Sweatshirts', 'Rash Guard', ...                0.25
# 657  ('Modern Pants', 'Socks', 'Rash Guard', ['Runn...                0.25
# 658  ('Modern Pants', 'Sweatshirts', 'Rash Guard', ...                0.20
# 659  ('Sweatshirts', 'Socks', 'Rash Guard', ['Runni...                0.25
# 660  ('Modern Pants', 'Sweatshirts', 'Tech Pants', ...                0.25
#
#      consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.50     0.30    1.000000  2.000000    0.1500         inf
# 1                  0.50     0.25    0.833333  1.666667    0.1000        3.00
# 2                  0.30     0.20    0.800000  2.666667    0.1250        3.50
# 3                  0.35     0.25    0.833333  2.380952    0.1450        3.90
# 4                  0.30     0.25    0.714286  2.380952    0.1450        2.45
# ..                  ...      ...         ...       ...       ...         ...
# 656                0.25     0.20    0.800000  3.200000    0.1375        3.75
# 657                0.25     0.20    0.800000  3.200000    0.1375        3.75
# 658                0.25     0.20    1.000000  4.000000    0.1500         inf
# 659                0.25     0.20    0.800000  3.200000    0.1375        3.75
# 660                0.20     0.20    0.800000  4.000000    0.1500        4.00
#
#      zhangs_metric
# 0         0.714286
# 1         0.571429
# 2         0.833333
# 3         0.828571
# 4         0.892308
# ..             ...
# 656       0.916667
# 657       0.916667
# 658       0.937500
# 659       0.916667
# 660       1.000000
#
# [661 rows x 10 columns]
# FP-Growth:
#                          antecedents  \
# 0                          ('Socks')
# 1                  (['Running Shoe')
# 2                    ('Sweatshirts')
# 3                    ('Sweatshirts')
# 4                          ('Socks')
# ..                               ...
# 656    ('Tech Pants', 'Soccer Shoe')
# 657   ('Sweatshirts', 'Soccer Shoe')
# 658  ('Modern Pants', 'Soccer Shoe')
# 659    ('Soccer Shoe', 'Rash Guard')
# 660                  ('Soccer Shoe')
#
#                                            consequents  antecedent support  \
# 0                                    (['Running Shoe')                0.55
# 1                                            ('Socks')                0.70
# 2                                    (['Running Shoe')                0.50
# 3                                            ('Socks')                0.50
# 4                                      ('Sweatshirts')                0.55
# ..                                                 ...                 ...
# 656      ('Modern Pants', 'Sweatshirts', 'Rash Guard')                0.25
# 657       ('Modern Pants', 'Tech Pants', 'Rash Guard')                0.20
# 658        ('Sweatshirts', 'Tech Pants', 'Rash Guard')                0.20
# 659      ('Modern Pants', 'Sweatshirts', 'Tech Pants')                0.20
# 660  ('Modern Pants', 'Sweatshirts', 'Tech Pants', ...                0.25
#
#      consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.70     0.50    0.909091  1.298701    0.1150    3.300000
# 1                  0.55     0.50    0.714286  1.298701    0.1150    1.575000
# 2                  0.70     0.45    0.900000  1.285714    0.1000    3.000000
# 3                  0.55     0.40    0.800000  1.454545    0.1250    2.250000
# 4                  0.50     0.40    0.727273  1.454545    0.1250    1.833333
# ..                  ...      ...         ...       ...       ...         ...
# 656                0.30     0.20    0.800000  2.666667    0.1250    3.500000
# 657                0.25     0.20    1.000000  4.000000    0.1500         inf
# 658                0.25     0.20    1.000000  4.000000    0.1500         inf
# 659                0.25     0.20    1.000000  4.000000    0.1500         inf
# 660                0.25     0.20    0.800000  3.200000    0.1375    3.750000
#
#      zhangs_metric
# 0         0.511111
# 1         0.766667
# 2         0.444444
# 3         0.625000
# 4         0.694444
# ..             ...
# 656       0.833333
# 657       0.937500
# 658       0.937500
# 659       0.937500
# 660       0.916667
#
# [661 rows x 10 columns]
#
# Flipkart Timing Performance:
# Brute-force Execution Time: 0.010076045989990234 seconds
# Apriori Execution Time: 0.03032398223876953 seconds
# FP-Growth Execution Time: 0.026259660720825195 seconds
#
# Flipkart Association Rules:
# Brute-force:
# [{"['Mobile Phones'"}, {"['Laptops'"}, {"'Televisions'"}, {"'Washing Machines'"}, {"'Air Conditioners'"}, {"'Cameras'"}, {"'Printers'"}, {"'Smart Watches']"}, {"'Refrigerators'"}, {"'Microwaves'"}, {"'Smart Watches']", "'Cameras'"}, {"'Smart Watches']", "['Mobile Phones'"}, {"'Air Conditioners'", "['Mobile Phones'"}, {"'Televisions'", "['Laptops'"}]
# Apriori:
#             antecedents         consequents  antecedent support  \
# 0  ('Air Conditioners')  (['Mobile Phones')                0.30
# 1           ('Cameras')  ('Smart Watches'])                0.25
# 2       ('Televisions')        (['Laptops')                0.35
# 3          (['Laptops')     ('Televisions')                0.35
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0                0.50     0.25    0.833333  1.666667    0.1000       3.000
# 1                0.30     0.20    0.800000  2.666667    0.1250       3.500
# 2                0.35     0.25    0.714286  2.040816    0.1275       2.275
# 3                0.35     0.25    0.714286  2.040816    0.1275       2.275
#
#    zhangs_metric
# 0       0.571429
# 1       0.833333
# 2       0.784615
# 3       0.784615
# FP-Growth:
#             antecedents         consequents  antecedent support  \
# 0       ('Televisions')        (['Laptops')                0.35
# 1          (['Laptops')     ('Televisions')                0.35
# 2  ('Air Conditioners')  (['Mobile Phones')                0.30
# 3           ('Cameras')  ('Smart Watches'])                0.25
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0                0.35     0.25    0.714286  2.040816    0.1275       2.275
# 1                0.35     0.25    0.714286  2.040816    0.1275       2.275
# 2                0.50     0.25    0.833333  1.666667    0.1000       3.000
# 3                0.30     0.20    0.800000  2.666667    0.1250       3.500
#
#    zhangs_metric
# 0       0.784615
# 1       0.784615
# 2       0.571429
# 3       0.833333
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# COMPARISON:

# Amazon Timing Performance:
# Brute-force Execution Time: 0.2229 seconds
# Apriori Execution Time: 0.0220 seconds
# FP-Growth Execution Time: 0.0220 seconds

# Best Buy Timing Performance:
# Brute-force Execution Time: 0.1811 seconds
# Apriori Execution Time: 0.0504 seconds
# FP-Growth Execution Time: 0.0320 seconds

# K-mart Timing Performance:
# Brute-force Execution Time: 0.1694 seconds
# Apriori Execution Time: 0.0351 seconds
# FP-Growth Execution Time: 0.0250 seconds

# Nike Timing Performance:
# Brute-force Execution Time: 2.1365 seconds
# Apriori Execution Time: 0.0470 seconds
# FP-Growth Execution Time: 0.0409 seconds

# Flipkart Timing Performance:
# Brute-force Execution Time: 0.0100 seconds
# Apriori Execution Time: 0.0180 seconds
# FP-Growth Execution Time: 0.0160 seconds

# Regarding whether the three algorithms produce the same results, it depends on the dataset and the support and confidence thresholds used.
# While the algorithms aim to find frequent itemsets and association rules, the specific implementation details may lead to slight variations in the results.
# It's essential to compare the association rules generated by each algorithm to determine if they are consistent across the board.

# In terms of speed, the FP-Growth algorithm tends to be faster compared to both the Brute-force and Apriori algorithms for most datasets.
# However, the actual performance may vary depending on the dataset size, itemset complexity, and the specific implementation of each algorithm.
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

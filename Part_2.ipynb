# %%
import pandas as pd
from itertools import combinations
# Function to generate frequent itemsets
def generate_frequent_itemsets(transactions, min_support):
    # Implementation of the brute force method
    item_counts = {}
    for transaction in transactions:
        for item in transaction:
            if item in item_counts:
                item_counts[item] += 1
            else:
                item_counts[item] = 1

    frequent_itemsets = []
    for item, count in item_counts.items():
        support = count / len(transactions)
        if support >= min_support:
            frequent_itemsets.append({item})

    k = 2
    while True:
        candidate_itemsets = set(combinations(item_counts.keys(), k))
        frequent_itemsets_k = []
        for candidate in candidate_itemsets:
            support = sum(1 for transaction in transactions if set(candidate).issubset(set(transaction))) / len(transactions)
            if support >= min_support:
                frequent_itemsets_k.append(set(candidate))
        if not frequent_itemsets_k:
            break
        frequent_itemsets.extend(frequent_itemsets_k)
        k += 1

    return frequent_itemsets

# %%
# Function to generate association rules
def generate_association_rules(frequent_itemsets, min_confidence):
    association_rules = []
    for itemset in frequent_itemsets:
        if len(itemset) >= 2:
            for i in range(1, len(itemset)):
                for antecedent in combinations(itemset, i):
                    antecedent = set(antecedent)
                    consequent = itemset - antecedent
                    antecedent_support = sum(1 for itemset in frequent_itemsets if antecedent.issubset(itemset)) / len(frequent_itemsets)
                    rule_confidence = len(itemset) / len(antecedent)
                    if rule_confidence >= min_confidence:
                        association_rules.append((antecedent, consequent, antecedent_support, rule_confidence))
    return association_rules

# %%
# Set minimum support and confidence
min_support = 0.2
min_confidence = 0.7

# Load transactions from CSV files for each dataset
amazon_transactions = pd.read_csv("amazon_transactions.csv")['Transaction'].apply(lambda x: set(x.split(", "))).tolist()
best_buy_transactions = pd.read_csv("best_buy_transactions.csv")['Transaction'].apply(lambda x: set(x.split(", "))).tolist()
k_mart_transactions = pd.read_csv("k_mart_transactions.csv")['Transaction'].apply(lambda x: set(x.split(", "))).tolist()
nike_transactions = pd.read_csv("nike_transactions.csv")['Transaction'].apply(lambda x: set(x.split(", "))).tolist()
flipkart_transactions = pd.read_csv("flipkart_transactions.csv")['Transaction'].apply(lambda x: set(x.split(", "))).tolist()

# Generate frequent itemsets and association rules for each dataset
datasets = {
    "Amazon": amazon_transactions,
    "Best Buy": best_buy_transactions,
    "K-mart": k_mart_transactions,
    "Nike": nike_transactions,
    "Flipkart": flipkart_transactions
}

for dataset_name, dataset_transactions in datasets.items():
    frequent_itemsets = generate_frequent_itemsets(dataset_transactions, min_support)
    association_rules = generate_association_rules(frequent_itemsets, min_confidence)
    print(f"\n{dataset_name} Frequent Itemsets:")
    for itemset in frequent_itemsets:
        print(itemset)
    print(f"\n{dataset_name} Association Rules:")
    for rule in association_rules:
        print(rule)
# Out:
# Amazon Frequent Itemsets:
# {"'Android Programming: The Big Nerd Ranch']"}
# {"['A Beginner’s Guide'"}
# {"'Java: The Complete Reference'"}
# {"'Java For Dummies'"}
# {"'Android Programming: The Big Nerd Ranch'"}
# {"'Head First Java 2nd Edition']"}
# {"['A Beginner’s Guide'", "'Android Programming: The Big Nerd Ranch']"}
# {"['A Beginner’s Guide'", "'Java: The Complete Reference'"}
# {"['A Beginner’s Guide'", "'Java For Dummies'"}
# {"'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}
# {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}
# {"'Java For Dummies'", "'Java: The Complete Reference'"}
# {"['A Beginner’s Guide'", "'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}
# {"['A Beginner’s Guide'", "'Java: The Complete Reference'", "'Java For Dummies'"}
# {"['A Beginner’s Guide'", "'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}
# {"'Java For Dummies'", "'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}
# {"['A Beginner’s Guide'", "'Java: The Complete Reference'", "'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}
#
# Amazon Association Rules:
# ({"['A Beginner’s Guide'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 2.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'"}, 0.47058823529411764, 2.0)
# ({"['A Beginner’s Guide'"}, {"'Java: The Complete Reference'"}, 0.47058823529411764, 2.0)
# ({"'Java: The Complete Reference'"}, {"['A Beginner’s Guide'"}, 0.47058823529411764, 2.0)
# ({"['A Beginner’s Guide'"}, {"'Java For Dummies'"}, 0.47058823529411764, 2.0)
# ({"'Java For Dummies'"}, {"['A Beginner’s Guide'"}, 0.47058823529411764, 2.0)
# ({"'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 2.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"'Java For Dummies'"}, 0.47058823529411764, 2.0)
# ({"'Java: The Complete Reference'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 2.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"'Java: The Complete Reference'"}, 0.47058823529411764, 2.0)
# ({"'Java For Dummies'"}, {"'Java: The Complete Reference'"}, 0.47058823529411764, 2.0)
# ({"'Java: The Complete Reference'"}, {"'Java For Dummies'"}, 0.47058823529411764, 2.0)
# ({"['A Beginner’s Guide'"}, {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 3.0)
# ({"'Java: The Complete Reference'"}, {"['A Beginner’s Guide'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 3.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'", "'Java: The Complete Reference'"}, 0.47058823529411764, 3.0)
# ({"['A Beginner’s Guide'", "'Java: The Complete Reference'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 1.5)
# ({"['A Beginner’s Guide'", "'Android Programming: The Big Nerd Ranch']"}, {"'Java: The Complete Reference'"}, 0.23529411764705882, 1.5)
# ({"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'"}, 0.23529411764705882, 1.5)
# ({"['A Beginner’s Guide'"}, {"'Java For Dummies'", "'Java: The Complete Reference'"}, 0.47058823529411764, 3.0)
# ({"'Java: The Complete Reference'"}, {"['A Beginner’s Guide'", "'Java For Dummies'"}, 0.47058823529411764, 3.0)
# ({"'Java For Dummies'"}, {"['A Beginner’s Guide'", "'Java: The Complete Reference'"}, 0.47058823529411764, 3.0)
# ({"['A Beginner’s Guide'", "'Java: The Complete Reference'"}, {"'Java For Dummies'"}, 0.23529411764705882, 1.5)
# ({"['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Java: The Complete Reference'"}, 0.23529411764705882, 1.5)
# ({"'Java For Dummies'", "'Java: The Complete Reference'"}, {"['A Beginner’s Guide'"}, 0.23529411764705882, 1.5)
# ({"['A Beginner’s Guide'"}, {"'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 3.0)
# ({"'Java For Dummies'"}, {"['A Beginner’s Guide'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 3.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'", "'Java For Dummies'"}, 0.47058823529411764, 3.0)
# ({"['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 1.5)
# ({"['A Beginner’s Guide'", "'Android Programming: The Big Nerd Ranch']"}, {"'Java For Dummies'"}, 0.23529411764705882, 1.5)
# ({"'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'"}, 0.23529411764705882, 1.5)
# ({"'Java For Dummies'"}, {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 3.0)
# ({"'Java: The Complete Reference'"}, {"'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 3.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"'Java For Dummies'", "'Java: The Complete Reference'"}, 0.47058823529411764, 3.0)
# ({"'Java For Dummies'", "'Java: The Complete Reference'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 1.5)
# ({"'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}, {"'Java: The Complete Reference'"}, 0.23529411764705882, 1.5)
# ({"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, {"'Java For Dummies'"}, 0.23529411764705882, 1.5)
# ({"['A Beginner’s Guide'"}, {"'Java For Dummies'", "'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 4.0)
# ({"'Java: The Complete Reference'"}, {"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'", "'Java For Dummies'"}, 0.47058823529411764, 4.0)
# ({"'Java For Dummies'"}, {"['A Beginner’s Guide'", "'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, 0.47058823529411764, 4.0)
# ({"'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'", "'Java: The Complete Reference'", "'Java For Dummies'"}, 0.47058823529411764, 4.0)
# ({"['A Beginner’s Guide'", "'Java: The Complete Reference'"}, {"'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 2.0)
# ({"['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 2.0)
# ({"['A Beginner’s Guide'", "'Android Programming: The Big Nerd Ranch']"}, {"'Java For Dummies'", "'Java: The Complete Reference'"}, 0.23529411764705882, 2.0)
# ({"'Java For Dummies'", "'Java: The Complete Reference'"}, {"['A Beginner’s Guide'", "'Android Programming: The Big Nerd Ranch']"}, 0.23529411764705882, 2.0)
# ({"'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'", "'Java For Dummies'"}, 0.23529411764705882, 2.0)
# ({"'Java For Dummies'", "'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'", "'Java: The Complete Reference'"}, 0.23529411764705882, 2.0)
# ({"['A Beginner’s Guide'", "'Java: The Complete Reference'", "'Java For Dummies'"}, {"'Android Programming: The Big Nerd Ranch']"}, 0.11764705882352941, 1.3333333333333333)
# ({"['A Beginner’s Guide'", "'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, {"'Java For Dummies'"}, 0.11764705882352941, 1.3333333333333333)
# ({"'Android Programming: The Big Nerd Ranch']", "['A Beginner’s Guide'", "'Java For Dummies'"}, {"'Java: The Complete Reference'"}, 0.11764705882352941, 1.3333333333333333)
# ({"'Java For Dummies'", "'Java: The Complete Reference'", "'Android Programming: The Big Nerd Ranch']"}, {"['A Beginner’s Guide'"}, 0.11764705882352941, 1.3333333333333333)
#
# Best Buy Frequent Itemsets:
# {"'Anti-Virus']"}
# {"'Microsoft Office'"}
# {"'Speakers'"}
# {"'Flash Drive'"}
# {"'Printer'"}
# {"['Lab Top'"}
# {"'Lab Top Case'"}
# {"'Anti-Virus'"}
# {"'External Hard Drive'"}
# {"['Digital Camera'"}
# {"'Speakers']"}
# {"'Lab Top'"}
# {"'Speakers']", "['Digital Camera'"}
# {"'Microsoft Office'", "'Anti-Virus'"}
# {"'Flash Drive'", "'Speakers'"}
# {"'Anti-Virus'", "['Digital Camera'"}
# {"'Flash Drive'", "'Anti-Virus']"}
# {"'Printer'", "'Anti-Virus'"}
# {"'Microsoft Office'", "'Flash Drive'"}
# {"['Lab Top'", "'Lab Top Case'"}
# {"'Lab Top Case'", "'Speakers'"}
# {"'Printer'", "'Flash Drive'"}
# {"'Flash Drive'", "'Lab Top Case'"}
# {"'Lab Top Case'", "'Anti-Virus']"}
# {"'Anti-Virus'", "'Lab Top Case'"}
# {"'Microsoft Office'", "'Lab Top Case'"}
# {"'Lab Top Case'", "['Digital Camera'"}
# {"'External Hard Drive'", "'Anti-Virus'"}
# {"'Printer'", "'Microsoft Office'"}
# {"['Lab Top'", "'Anti-Virus']"}
# {"'Printer'", "'Lab Top Case'"}
# {"'External Hard Drive'", "'Lab Top Case'"}
# {"'Speakers']", "'Lab Top Case'"}
# {"'Flash Drive'", "['Digital Camera'"}
# {"'Flash Drive'", "['Lab Top'"}
# {"'Lab Top'", "['Digital Camera'"}
# {"'Microsoft Office'", "'Speakers'"}
# {"'Flash Drive'", "'Anti-Virus'"}
# {"'Flash Drive'", "'Anti-Virus'", "'Lab Top Case'"}
# {"'Microsoft Office'", "'Lab Top Case'", "'Flash Drive'"}
# {"'Printer'", "'Flash Drive'", "'Anti-Virus'"}
# {"'Speakers']", "'Lab Top Case'", "['Digital Camera'"}
# {"'Printer'", "'Microsoft Office'", "'Flash Drive'"}
# {"'Microsoft Office'", "'Anti-Virus'", "'Flash Drive'"}
# {"'Microsoft Office'", "'Speakers'", "'Flash Drive'"}
# {"'Microsoft Office'", "'Anti-Virus'", "'Lab Top Case'"}
# {"'Printer'", "'Microsoft Office'", "'Lab Top Case'"}
# {"'Printer'", "'Flash Drive'", "'Lab Top Case'"}
# {"'Microsoft Office'", "'Anti-Virus'", "'Lab Top Case'", "'Flash Drive'"}
# {"'Printer'", "'Microsoft Office'", "'Lab Top Case'", "'Flash Drive'"}
#
# Best Buy Association Rules:
# ({"'Speakers']"}, {"['Digital Camera'"}, 0.08, 2.0)
# ({"['Digital Camera'"}, {"'Speakers']"}, 0.14, 2.0)
# ({"'Microsoft Office'"}, {"'Anti-Virus'"}, 0.28, 2.0)
# ({"'Anti-Virus'"}, {"'Microsoft Office'"}, 0.24, 2.0)
# ({"'Flash Drive'"}, {"'Speakers'"}, 0.36, 2.0)
# ({"'Speakers'"}, {"'Flash Drive'"}, 0.1, 2.0)
# ({"'Anti-Virus'"}, {"['Digital Camera'"}, 0.24, 2.0)
# ({"['Digital Camera'"}, {"'Anti-Virus'"}, 0.14, 2.0)
# ({"'Flash Drive'"}, {"'Anti-Virus']"}, 0.36, 2.0)
# ({"'Anti-Virus']"}, {"'Flash Drive'"}, 0.08, 2.0)
# ({"'Printer'"}, {"'Anti-Virus'"}, 0.2, 2.0)
# ({"'Anti-Virus'"}, {"'Printer'"}, 0.24, 2.0)
# ({"'Microsoft Office'"}, {"'Flash Drive'"}, 0.28, 2.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'"}, 0.36, 2.0)
# ({"['Lab Top'"}, {"'Lab Top Case'"}, 0.08, 2.0)
# ({"'Lab Top Case'"}, {"['Lab Top'"}, 0.38, 2.0)
# ({"'Lab Top Case'"}, {"'Speakers'"}, 0.38, 2.0)
# ({"'Speakers'"}, {"'Lab Top Case'"}, 0.1, 2.0)
# ({"'Printer'"}, {"'Flash Drive'"}, 0.2, 2.0)
# ({"'Flash Drive'"}, {"'Printer'"}, 0.36, 2.0)
# ({"'Flash Drive'"}, {"'Lab Top Case'"}, 0.36, 2.0)
# ({"'Lab Top Case'"}, {"'Flash Drive'"}, 0.38, 2.0)
# ({"'Lab Top Case'"}, {"'Anti-Virus']"}, 0.38, 2.0)
# ({"'Anti-Virus']"}, {"'Lab Top Case'"}, 0.08, 2.0)
# ({"'Anti-Virus'"}, {"'Lab Top Case'"}, 0.24, 2.0)
# ({"'Lab Top Case'"}, {"'Anti-Virus'"}, 0.38, 2.0)
# ({"'Microsoft Office'"}, {"'Lab Top Case'"}, 0.28, 2.0)
# ({"'Lab Top Case'"}, {"'Microsoft Office'"}, 0.38, 2.0)
# ({"'Lab Top Case'"}, {"['Digital Camera'"}, 0.38, 2.0)
# ({"['Digital Camera'"}, {"'Lab Top Case'"}, 0.14, 2.0)
# ({"'External Hard Drive'"}, {"'Anti-Virus'"}, 0.06, 2.0)
# ({"'Anti-Virus'"}, {"'External Hard Drive'"}, 0.24, 2.0)
# ({"'Printer'"}, {"'Microsoft Office'"}, 0.2, 2.0)
# ({"'Microsoft Office'"}, {"'Printer'"}, 0.28, 2.0)
# ({"['Lab Top'"}, {"'Anti-Virus']"}, 0.08, 2.0)
# ({"'Anti-Virus']"}, {"['Lab Top'"}, 0.08, 2.0)
# ({"'Printer'"}, {"'Lab Top Case'"}, 0.2, 2.0)
# ({"'Lab Top Case'"}, {"'Printer'"}, 0.38, 2.0)
# ({"'External Hard Drive'"}, {"'Lab Top Case'"}, 0.06, 2.0)
# ({"'Lab Top Case'"}, {"'External Hard Drive'"}, 0.38, 2.0)
# ({"'Speakers']"}, {"'Lab Top Case'"}, 0.08, 2.0)
# ({"'Lab Top Case'"}, {"'Speakers']"}, 0.38, 2.0)
# ({"'Flash Drive'"}, {"['Digital Camera'"}, 0.36, 2.0)
# ({"['Digital Camera'"}, {"'Flash Drive'"}, 0.14, 2.0)
# ({"'Flash Drive'"}, {"['Lab Top'"}, 0.36, 2.0)
# ({"['Lab Top'"}, {"'Flash Drive'"}, 0.08, 2.0)
# ({"'Lab Top'"}, {"['Digital Camera'"}, 0.04, 2.0)
# ({"['Digital Camera'"}, {"'Lab Top'"}, 0.14, 2.0)
# ({"'Microsoft Office'"}, {"'Speakers'"}, 0.28, 2.0)
# ({"'Speakers'"}, {"'Microsoft Office'"}, 0.1, 2.0)
# ({"'Flash Drive'"}, {"'Anti-Virus'"}, 0.36, 2.0)
# ({"'Anti-Virus'"}, {"'Flash Drive'"}, 0.24, 2.0)
# ({"'Flash Drive'"}, {"'Lab Top Case'", "'Anti-Virus'"}, 0.36, 3.0)
# ({"'Anti-Virus'"}, {"'Flash Drive'", "'Lab Top Case'"}, 0.24, 3.0)
# ({"'Lab Top Case'"}, {"'Flash Drive'", "'Anti-Virus'"}, 0.38, 3.0)
# ({"'Flash Drive'", "'Anti-Virus'"}, {"'Lab Top Case'"}, 0.1, 1.5)
# ({"'Flash Drive'", "'Lab Top Case'"}, {"'Anti-Virus'"}, 0.12, 1.5)
# ({"'Lab Top Case'", "'Anti-Virus'"}, {"'Flash Drive'"}, 0.08, 1.5)
# ({"'Microsoft Office'"}, {"'Flash Drive'", "'Lab Top Case'"}, 0.28, 3.0)
# ({"'Lab Top Case'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.38, 3.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'", "'Lab Top Case'"}, 0.36, 3.0)
# ({"'Microsoft Office'", "'Lab Top Case'"}, {"'Flash Drive'"}, 0.12, 1.5)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.14, 1.5)
# ({"'Flash Drive'", "'Lab Top Case'"}, {"'Microsoft Office'"}, 0.12, 1.5)
# ({"'Printer'"}, {"'Flash Drive'", "'Anti-Virus'"}, 0.2, 3.0)
# ({"'Flash Drive'"}, {"'Printer'", "'Anti-Virus'"}, 0.36, 3.0)
# ({"'Anti-Virus'"}, {"'Printer'", "'Flash Drive'"}, 0.24, 3.0)
# ({"'Printer'", "'Flash Drive'"}, {"'Anti-Virus'"}, 0.1, 1.5)
# ({"'Printer'", "'Anti-Virus'"}, {"'Flash Drive'"}, 0.04, 1.5)
# ({"'Flash Drive'", "'Anti-Virus'"}, {"'Printer'"}, 0.1, 1.5)
# ({"'Speakers']"}, {"'Lab Top Case'", "['Digital Camera'"}, 0.08, 3.0)
# ({"'Lab Top Case'"}, {"'Speakers']", "['Digital Camera'"}, 0.38, 3.0)
# ({"['Digital Camera'"}, {"'Speakers']", "'Lab Top Case'"}, 0.14, 3.0)
# ({"'Speakers']", "'Lab Top Case'"}, {"['Digital Camera'"}, 0.04, 1.5)
# ({"'Speakers']", "['Digital Camera'"}, {"'Lab Top Case'"}, 0.04, 1.5)
# ({"'Lab Top Case'", "['Digital Camera'"}, {"'Speakers']"}, 0.04, 1.5)
# ({"'Printer'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.2, 3.0)
# ({"'Microsoft Office'"}, {"'Printer'", "'Flash Drive'"}, 0.28, 3.0)
# ({"'Flash Drive'"}, {"'Printer'", "'Microsoft Office'"}, 0.36, 3.0)
# ({"'Printer'", "'Microsoft Office'"}, {"'Flash Drive'"}, 0.08, 1.5)
# ({"'Printer'", "'Flash Drive'"}, {"'Microsoft Office'"}, 0.1, 1.5)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Printer'"}, 0.14, 1.5)
# ({"'Microsoft Office'"}, {"'Flash Drive'", "'Anti-Virus'"}, 0.28, 3.0)
# ({"'Anti-Virus'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.24, 3.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'", "'Anti-Virus'"}, 0.36, 3.0)
# ({"'Microsoft Office'", "'Anti-Virus'"}, {"'Flash Drive'"}, 0.08, 1.5)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Anti-Virus'"}, 0.14, 1.5)
# ({"'Flash Drive'", "'Anti-Virus'"}, {"'Microsoft Office'"}, 0.1, 1.5)
# ({"'Microsoft Office'"}, {"'Flash Drive'", "'Speakers'"}, 0.28, 3.0)
# ({"'Speakers'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.1, 3.0)
# ({"'Flash Drive'"}, {"'Microsoft Office'", "'Speakers'"}, 0.36, 3.0)
# ({"'Microsoft Office'", "'Speakers'"}, {"'Flash Drive'"}, 0.04, 1.5)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Speakers'"}, 0.14, 1.5)
# ({"'Flash Drive'", "'Speakers'"}, {"'Microsoft Office'"}, 0.04, 1.5)
# ({"'Microsoft Office'"}, {"'Lab Top Case'", "'Anti-Virus'"}, 0.28, 3.0)
# ({"'Anti-Virus'"}, {"'Microsoft Office'", "'Lab Top Case'"}, 0.24, 3.0)
# ({"'Lab Top Case'"}, {"'Microsoft Office'", "'Anti-Virus'"}, 0.38, 3.0)
# ({"'Microsoft Office'", "'Anti-Virus'"}, {"'Lab Top Case'"}, 0.08, 1.5)
# ({"'Microsoft Office'", "'Lab Top Case'"}, {"'Anti-Virus'"}, 0.12, 1.5)
# ({"'Lab Top Case'", "'Anti-Virus'"}, {"'Microsoft Office'"}, 0.08, 1.5)
# ({"'Printer'"}, {"'Microsoft Office'", "'Lab Top Case'"}, 0.2, 3.0)
# ({"'Microsoft Office'"}, {"'Printer'", "'Lab Top Case'"}, 0.28, 3.0)
# ({"'Lab Top Case'"}, {"'Printer'", "'Microsoft Office'"}, 0.38, 3.0)
# ({"'Printer'", "'Microsoft Office'"}, {"'Lab Top Case'"}, 0.08, 1.5)
# ({"'Printer'", "'Lab Top Case'"}, {"'Microsoft Office'"}, 0.08, 1.5)
# ({"'Microsoft Office'", "'Lab Top Case'"}, {"'Printer'"}, 0.12, 1.5)
# ({"'Printer'"}, {"'Flash Drive'", "'Lab Top Case'"}, 0.2, 3.0)
# ({"'Flash Drive'"}, {"'Printer'", "'Lab Top Case'"}, 0.36, 3.0)
# ({"'Lab Top Case'"}, {"'Printer'", "'Flash Drive'"}, 0.38, 3.0)
# ({"'Printer'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.1, 1.5)
# ({"'Printer'", "'Lab Top Case'"}, {"'Flash Drive'"}, 0.08, 1.5)
# ({"'Flash Drive'", "'Lab Top Case'"}, {"'Printer'"}, 0.12, 1.5)
# ({"'Microsoft Office'"}, {"'Lab Top Case'", "'Flash Drive'", "'Anti-Virus'"}, 0.28, 4.0)
# ({"'Anti-Virus'"}, {"'Microsoft Office'", "'Lab Top Case'", "'Flash Drive'"}, 0.24, 4.0)
# ({"'Lab Top Case'"}, {"'Microsoft Office'", "'Anti-Virus'", "'Flash Drive'"}, 0.38, 4.0)
# ({"'Flash Drive'"}, {"'Lab Top Case'", "'Microsoft Office'", "'Anti-Virus'"}, 0.36, 4.0)
# ({"'Microsoft Office'", "'Anti-Virus'"}, {"'Flash Drive'", "'Lab Top Case'"}, 0.08, 2.0)
# ({"'Microsoft Office'", "'Lab Top Case'"}, {"'Flash Drive'", "'Anti-Virus'"}, 0.12, 2.0)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Lab Top Case'", "'Anti-Virus'"}, 0.14, 2.0)
# ({"'Lab Top Case'", "'Anti-Virus'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.08, 2.0)
# ({"'Flash Drive'", "'Anti-Virus'"}, {"'Microsoft Office'", "'Lab Top Case'"}, 0.1, 2.0)
# ({"'Flash Drive'", "'Lab Top Case'"}, {"'Microsoft Office'", "'Anti-Virus'"}, 0.12, 2.0)
# ({"'Lab Top Case'", "'Microsoft Office'", "'Anti-Virus'"}, {"'Flash Drive'"}, 0.04, 1.3333333333333333)
# ({"'Microsoft Office'", "'Anti-Virus'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.04, 1.3333333333333333)
# ({"'Microsoft Office'", "'Lab Top Case'", "'Flash Drive'"}, {"'Anti-Virus'"}, 0.06, 1.3333333333333333)
# ({"'Lab Top Case'", "'Flash Drive'", "'Anti-Virus'"}, {"'Microsoft Office'"}, 0.04, 1.3333333333333333)
# ({"'Printer'"}, {"'Microsoft Office'", "'Lab Top Case'", "'Flash Drive'"}, 0.2, 4.0)
# ({"'Microsoft Office'"}, {"'Printer'", "'Flash Drive'", "'Lab Top Case'"}, 0.28, 4.0)
# ({"'Lab Top Case'"}, {"'Printer'", "'Microsoft Office'", "'Flash Drive'"}, 0.38, 4.0)
# ({"'Flash Drive'"}, {"'Printer'", "'Microsoft Office'", "'Lab Top Case'"}, 0.36, 4.0)
# ({"'Printer'", "'Microsoft Office'"}, {"'Flash Drive'", "'Lab Top Case'"}, 0.08, 2.0)
# ({"'Printer'", "'Lab Top Case'"}, {"'Microsoft Office'", "'Flash Drive'"}, 0.08, 2.0)
# ({"'Printer'", "'Flash Drive'"}, {"'Microsoft Office'", "'Lab Top Case'"}, 0.1, 2.0)
# ({"'Microsoft Office'", "'Lab Top Case'"}, {"'Printer'", "'Flash Drive'"}, 0.12, 2.0)
# ({"'Microsoft Office'", "'Flash Drive'"}, {"'Printer'", "'Lab Top Case'"}, 0.14, 2.0)
# ({"'Flash Drive'", "'Lab Top Case'"}, {"'Printer'", "'Microsoft Office'"}, 0.12, 2.0)
# ({"'Printer'", "'Microsoft Office'", "'Lab Top Case'"}, {"'Flash Drive'"}, 0.04, 1.3333333333333333)
# ({"'Printer'", "'Microsoft Office'", "'Flash Drive'"}, {"'Lab Top Case'"}, 0.04, 1.3333333333333333)
# ({"'Printer'", "'Flash Drive'", "'Lab Top Case'"}, {"'Microsoft Office'"}, 0.04, 1.3333333333333333)
# ({"'Microsoft Office'", "'Lab Top Case'", "'Flash Drive'"}, {"'Printer'"}, 0.06, 1.3333333333333333)
#
# K-mart Frequent Itemsets:
# {"['Decorative Pillows'"}
# {"'Kids Bedding'"}
# {"'Sheets']"}
# {"'Bed Skirts'"}
# {"'Shams'"}
# {"'Bedspreads'"}
# {"'Sheets'"}
# {"'Kids Bedding']"}
# {"'Kids Bedding'", "'Shams'"}
# {"'Kids Bedding'", "'Bed Skirts'"}
# {"'Sheets']", "'Bed Skirts'"}
# {"'Bed Skirts'", "'Shams'"}
# {"'Shams'", "'Bedspreads'"}
# {"'Kids Bedding'", "'Sheets']"}
# {"'Bed Skirts'", "'Bedspreads'"}
# {"'Kids Bedding'", "'Bed Skirts'", "'Sheets']"}
# {"'Bed Skirts'", "'Shams'", "'Bedspreads'"}
#
# K-mart Association Rules:
# ({"'Kids Bedding'"}, {"'Shams'"}, 0.29411764705882354, 2.0)
# ({"'Shams'"}, {"'Kids Bedding'"}, 0.29411764705882354, 2.0)
# ({"'Kids Bedding'"}, {"'Bed Skirts'"}, 0.29411764705882354, 2.0)
# ({"'Bed Skirts'"}, {"'Kids Bedding'"}, 0.4117647058823529, 2.0)
# ({"'Sheets']"}, {"'Bed Skirts'"}, 0.23529411764705882, 2.0)
# ({"'Bed Skirts'"}, {"'Sheets']"}, 0.4117647058823529, 2.0)
# ({"'Bed Skirts'"}, {"'Shams'"}, 0.4117647058823529, 2.0)
# ({"'Shams'"}, {"'Bed Skirts'"}, 0.29411764705882354, 2.0)
# ({"'Shams'"}, {"'Bedspreads'"}, 0.29411764705882354, 2.0)
# ({"'Bedspreads'"}, {"'Shams'"}, 0.23529411764705882, 2.0)
# ({"'Kids Bedding'"}, {"'Sheets']"}, 0.29411764705882354, 2.0)
# ({"'Sheets']"}, {"'Kids Bedding'"}, 0.23529411764705882, 2.0)
# ({"'Bed Skirts'"}, {"'Bedspreads'"}, 0.4117647058823529, 2.0)
# ({"'Bedspreads'"}, {"'Bed Skirts'"}, 0.23529411764705882, 2.0)
# ({"'Kids Bedding'"}, {"'Sheets']", "'Bed Skirts'"}, 0.29411764705882354, 3.0)
# ({"'Bed Skirts'"}, {"'Kids Bedding'", "'Sheets']"}, 0.4117647058823529, 3.0)
# ({"'Sheets']"}, {"'Kids Bedding'", "'Bed Skirts'"}, 0.23529411764705882, 3.0)
# ({"'Kids Bedding'", "'Bed Skirts'"}, {"'Sheets']"}, 0.11764705882352941, 1.5)
# ({"'Kids Bedding'", "'Sheets']"}, {"'Bed Skirts'"}, 0.11764705882352941, 1.5)
# ({"'Sheets']", "'Bed Skirts'"}, {"'Kids Bedding'"}, 0.11764705882352941, 1.5)
# ({"'Bed Skirts'"}, {"'Shams'", "'Bedspreads'"}, 0.4117647058823529, 3.0)
# ({"'Shams'"}, {"'Bed Skirts'", "'Bedspreads'"}, 0.29411764705882354, 3.0)
# ({"'Bedspreads'"}, {"'Bed Skirts'", "'Shams'"}, 0.23529411764705882, 3.0)
# ({"'Bed Skirts'", "'Shams'"}, {"'Bedspreads'"}, 0.11764705882352941, 1.5)
# ({"'Bed Skirts'", "'Bedspreads'"}, {"'Shams'"}, 0.11764705882352941, 1.5)
# ({"'Shams'", "'Bedspreads'"}, {"'Bed Skirts'"}, 0.11764705882352941, 1.5)
#
# Nike Frequent Itemsets:
# {"'Socks'"}
# {"['Running Shoe'"}
# {"'Sweatshirts'"}
# {"'Modern Pants'"}
# {"'Tech Pants'"}
# {"'Rash Guard'"}
# {"['Swimming Shirt'"}
# {"'Dry Fit V-Nick'"}
# {"'Hoodies'"}
# {"'Dry Fit V-Nick']"}
# {"'Swimming Shirt'"}
# {"'Soccer Shoe'"}
# {"'Swimming Shirt'", "'Rash Guard'"}
# {"'Modern Pants'", "'Rash Guard'"}
# {"'Socks'", "['Running Shoe'"}
# {"'Modern Pants'", "['Running Shoe'"}
# {"'Rash Guard'", "'Hoodies'"}
# {"'Soccer Shoe'", "'Hoodies'"}
# {"'Tech Pants'", "'Dry Fit V-Nick']"}
# {"'Socks'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Sweatshirts'"}
# {"['Running Shoe'", "'Sweatshirts'"}
# {"'Socks'", "'Swimming Shirt'"}
# {"['Running Shoe'", "'Swimming Shirt'"}
# {"'Tech Pants'", "'Sweatshirts'"}
# {"'Socks'", "'Rash Guard'"}
# {"'Modern Pants'", "'Soccer Shoe'"}
# {"'Tech Pants'", "'Swimming Shirt'"}
# {"'Soccer Shoe'", "'Rash Guard'"}
# {"'Swimming Shirt'", "'Sweatshirts'"}
# {"'Tech Pants'", "'Rash Guard'"}
# {"'Dry Fit V-Nick']", "'Hoodies'"}
# {"'Tech Pants'", "'Hoodies'"}
# {"'Modern Pants'", "'Tech Pants'"}
# {"['Running Shoe'", "'Rash Guard'"}
# {"'Rash Guard'", "'Dry Fit V-Nick']"}
# {"'Socks'", "'Modern Pants'"}
# {"'Soccer Shoe'", "'Tech Pants'"}
# {"'Rash Guard'", "'Sweatshirts'"}
# {"'Soccer Shoe'", "'Sweatshirts'"}
# {"'Socks'", "'Tech Pants'"}
# {"['Running Shoe'", "'Tech Pants'"}
# {"'Modern Pants'", "'Swimming Shirt'"}
# {"'Socks'", "['Running Shoe'", "'Sweatshirts'"}
# {"['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Soccer Shoe'", "'Tech Pants'"}
# {"['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}
# {"'Socks'", "['Running Shoe'", "'Rash Guard'"}
# {"'Modern Pants'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Swimming Shirt'", "'Rash Guard'"}
# {"'Socks'", "'Modern Pants'", "'Sweatshirts'"}
# {"'Tech Pants'", "'Swimming Shirt'", "'Rash Guard'"}
# {"'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Soccer Shoe'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Modern Pants'", "['Running Shoe'", "'Sweatshirts'"}
# {"'Socks'", "['Running Shoe'", "'Modern Pants'"}
# {"'Rash Guard'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Rash Guard'", "'Sweatshirts'"}
# {"'Socks'", "'Tech Pants'", "'Rash Guard'"}
# {"'Modern Pants'", "'Soccer Shoe'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Soccer Shoe'", "'Rash Guard'"}
# {"'Socks'", "'Tech Pants'", "'Modern Pants'"}
# {"'Socks'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Dry Fit V-Nick']", "'Rash Guard'", "'Hoodies'"}
# {"['Running Shoe'", "'Tech Pants'", "'Swimming Shirt'"}
# {"'Tech Pants'", "'Rash Guard'", "'Hoodies'"}
# {"'Socks'", "'Modern Pants'", "'Swimming Shirt'"}
# {"['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}
# {"'Dry Fit V-Nick']", "'Tech Pants'", "'Hoodies'"}
# {"'Socks'", "'Modern Pants'", "'Rash Guard'"}
# {"'Socks'", "['Running Shoe'", "'Tech Pants'"}
# {"'Soccer Shoe'", "'Tech Pants'", "'Rash Guard'"}
# {"'Modern Pants'", "['Running Shoe'", "'Tech Pants'"}
# {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'"}
# {"'Socks'", "['Running Shoe'", "'Swimming Shirt'"}
# {"'Socks'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Soccer Shoe'", "'Tech Pants'", "'Hoodies'"}
# {"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'"}
# {"'Modern Pants'", "['Running Shoe'", "'Rash Guard'"}
# {"'Rash Guard'", "'Soccer Shoe'", "'Sweatshirts'"}
# {"'Tech Pants'", "'Rash Guard'", "'Dry Fit V-Nick']"}
# {"'Socks'", "'Rash Guard'", "'Sweatshirts'"}
# {"['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Socks'", "'Swimming Shirt'", "'Rash Guard'"}
# {"'Modern Pants'", "['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}
# {"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}
# {"'Socks'", "'Rash Guard'", "'Modern Pants'", "'Sweatshirts'"}
# {"'Socks'", "['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}
# {"'Rash Guard'", "'Soccer Shoe'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Socks'", "'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Socks'", "'Tech Pants'", "'Modern Pants'", "'Sweatshirts'"}
# {"'Socks'", "'Tech Pants'", "'Modern Pants'", "'Rash Guard'"}
# {"'Socks'", "['Running Shoe'", "'Modern Pants'", "'Sweatshirts'"}
# {"'Socks'", "'Rash Guard'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Socks'", "['Running Shoe'", "'Modern Pants'", "'Swimming Shirt'"}
# {"'Modern Pants'", "'Rash Guard'", "'Soccer Shoe'", "'Sweatshirts'"}
# {"'Socks'", "['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Socks'", "'Modern Pants'", "'Sweatshirts'", "'Swimming Shirt'"}
# {"'Modern Pants'", "'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Soccer Shoe'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Dry Fit V-Nick']", "'Tech Pants'", "'Rash Guard'", "'Hoodies'"}
# {"'Modern Pants'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Soccer Shoe'", "'Tech Pants'", "'Rash Guard'"}
# {"'Socks'", "'Modern Pants'", "'Rash Guard'", "'Swimming Shirt'"}
# {"'Socks'", "['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}
# {"'Socks'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}
# {"'Rash Guard'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Modern Pants'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Rash Guard'", "['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Modern Pants'", "'Rash Guard'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Socks'", "['Running Shoe'", "'Tech Pants'", "'Modern Pants'"}
# {"['Running Shoe'", "'Tech Pants'", "'Swimming Shirt'", "'Rash Guard'"}
# {"'Socks'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}
# {"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}
# {"'Socks'", "['Running Shoe'", "'Modern Pants'", "'Rash Guard'"}
# {"'Modern Pants'", "'Sweatshirts'", "['Running Shoe'", "'Rash Guard'", "'Swimming Shirt'"}
# {"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'", "'Swimming Shirt'"}
# {"'Modern Pants'", "'Tech Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Rash Guard'", "'Soccer Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Socks'", "['Running Shoe'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Swimming Shirt'"}
# {"'Sweatshirts'", "'Tech Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Socks'", "'Rash Guard'", "'Swimming Shirt'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "['Running Shoe'", "'Rash Guard'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Socks'", "'Rash Guard'"}
# {"'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Rash Guard'", "'Swimming Shirt'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Rash Guard'", "'Swimming Shirt'"}
# {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}
#
# Nike Association Rules:
# ({"'Swimming Shirt'"}, {"'Rash Guard'"}, 0.2748091603053435, 2.0)
# ({"'Rash Guard'"}, {"'Swimming Shirt'"}, 0.48854961832061067, 2.0)
# ({"'Modern Pants'"}, {"'Rash Guard'"}, 0.42748091603053434, 2.0)
# ({"'Rash Guard'"}, {"'Modern Pants'"}, 0.48854961832061067, 2.0)
# ({"'Socks'"}, {"['Running Shoe'"}, 0.366412213740458, 2.0)
# ({"['Running Shoe'"}, {"'Socks'"}, 0.3816793893129771, 2.0)
# ({"'Modern Pants'"}, {"['Running Shoe'"}, 0.42748091603053434, 2.0)
# ({"['Running Shoe'"}, {"'Modern Pants'"}, 0.3816793893129771, 2.0)
# ({"'Rash Guard'"}, {"'Hoodies'"}, 0.48854961832061067, 2.0)
# ({"'Hoodies'"}, {"'Rash Guard'"}, 0.07633587786259542, 2.0)
# ({"'Soccer Shoe'"}, {"'Hoodies'"}, 0.13740458015267176, 2.0)
# ({"'Hoodies'"}, {"'Soccer Shoe'"}, 0.07633587786259542, 2.0)
# ({"'Tech Pants'"}, {"'Dry Fit V-Nick']"}, 0.3893129770992366, 2.0)
# ({"'Dry Fit V-Nick']"}, {"'Tech Pants'"}, 0.061068702290076333, 2.0)
# ({"'Socks'"}, {"'Sweatshirts'"}, 0.366412213740458, 2.0)
# ({"'Sweatshirts'"}, {"'Socks'"}, 0.42748091603053434, 2.0)
# ({"'Modern Pants'"}, {"'Sweatshirts'"}, 0.42748091603053434, 2.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'"}, 0.42748091603053434, 2.0)
# ({"['Running Shoe'"}, {"'Sweatshirts'"}, 0.3816793893129771, 2.0)
# ({"'Sweatshirts'"}, {"['Running Shoe'"}, 0.42748091603053434, 2.0)
# ({"'Socks'"}, {"'Swimming Shirt'"}, 0.366412213740458, 2.0)
# ({"'Swimming Shirt'"}, {"'Socks'"}, 0.2748091603053435, 2.0)
# ({"['Running Shoe'"}, {"'Swimming Shirt'"}, 0.3816793893129771, 2.0)
# ({"'Swimming Shirt'"}, {"['Running Shoe'"}, 0.2748091603053435, 2.0)
# ({"'Tech Pants'"}, {"'Sweatshirts'"}, 0.3893129770992366, 2.0)
# ({"'Sweatshirts'"}, {"'Tech Pants'"}, 0.42748091603053434, 2.0)
# ({"'Socks'"}, {"'Rash Guard'"}, 0.366412213740458, 2.0)
# ({"'Rash Guard'"}, {"'Socks'"}, 0.48854961832061067, 2.0)
# ({"'Modern Pants'"}, {"'Soccer Shoe'"}, 0.42748091603053434, 2.0)
# ({"'Soccer Shoe'"}, {"'Modern Pants'"}, 0.13740458015267176, 2.0)
# ({"'Tech Pants'"}, {"'Swimming Shirt'"}, 0.3893129770992366, 2.0)
# ({"'Swimming Shirt'"}, {"'Tech Pants'"}, 0.2748091603053435, 2.0)
# ({"'Soccer Shoe'"}, {"'Rash Guard'"}, 0.13740458015267176, 2.0)
# ({"'Rash Guard'"}, {"'Soccer Shoe'"}, 0.48854961832061067, 2.0)
# ({"'Swimming Shirt'"}, {"'Sweatshirts'"}, 0.2748091603053435, 2.0)
# ({"'Sweatshirts'"}, {"'Swimming Shirt'"}, 0.42748091603053434, 2.0)
# ({"'Tech Pants'"}, {"'Rash Guard'"}, 0.3893129770992366, 2.0)
# ({"'Rash Guard'"}, {"'Tech Pants'"}, 0.48854961832061067, 2.0)
# ({"'Dry Fit V-Nick']"}, {"'Hoodies'"}, 0.061068702290076333, 2.0)
# ({"'Hoodies'"}, {"'Dry Fit V-Nick']"}, 0.07633587786259542, 2.0)
# ({"'Tech Pants'"}, {"'Hoodies'"}, 0.3893129770992366, 2.0)
# ({"'Hoodies'"}, {"'Tech Pants'"}, 0.07633587786259542, 2.0)
# ({"'Modern Pants'"}, {"'Tech Pants'"}, 0.42748091603053434, 2.0)
# ({"'Tech Pants'"}, {"'Modern Pants'"}, 0.3893129770992366, 2.0)
# ({"['Running Shoe'"}, {"'Rash Guard'"}, 0.3816793893129771, 2.0)
# ({"'Rash Guard'"}, {"['Running Shoe'"}, 0.48854961832061067, 2.0)
# ({"'Rash Guard'"}, {"'Dry Fit V-Nick']"}, 0.48854961832061067, 2.0)
# ({"'Dry Fit V-Nick']"}, {"'Rash Guard'"}, 0.061068702290076333, 2.0)
# ({"'Socks'"}, {"'Modern Pants'"}, 0.366412213740458, 2.0)
# ({"'Modern Pants'"}, {"'Socks'"}, 0.42748091603053434, 2.0)
# ({"'Soccer Shoe'"}, {"'Tech Pants'"}, 0.13740458015267176, 2.0)
# ({"'Tech Pants'"}, {"'Soccer Shoe'"}, 0.3893129770992366, 2.0)
# ({"'Rash Guard'"}, {"'Sweatshirts'"}, 0.48854961832061067, 2.0)
# ({"'Sweatshirts'"}, {"'Rash Guard'"}, 0.42748091603053434, 2.0)
# ({"'Soccer Shoe'"}, {"'Sweatshirts'"}, 0.13740458015267176, 2.0)
# ({"'Sweatshirts'"}, {"'Soccer Shoe'"}, 0.42748091603053434, 2.0)
# ({"'Socks'"}, {"'Tech Pants'"}, 0.366412213740458, 2.0)
# ({"'Tech Pants'"}, {"'Socks'"}, 0.3893129770992366, 2.0)
# ({"['Running Shoe'"}, {"'Tech Pants'"}, 0.3816793893129771, 2.0)
# ({"'Tech Pants'"}, {"['Running Shoe'"}, 0.3893129770992366, 2.0)
# ({"'Modern Pants'"}, {"'Swimming Shirt'"}, 0.42748091603053434, 2.0)
# ({"'Swimming Shirt'"}, {"'Modern Pants'"}, 0.2748091603053435, 2.0)
# ({"'Socks'"}, {"['Running Shoe'", "'Sweatshirts'"}, 0.366412213740458, 3.0)
# ({"['Running Shoe'"}, {"'Socks'", "'Sweatshirts'"}, 0.3816793893129771, 3.0)
# ({"'Sweatshirts'"}, {"'Socks'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Socks'", "['Running Shoe'"}, {"'Sweatshirts'"}, 0.183206106870229, 1.5)
# ({"'Socks'", "'Sweatshirts'"}, {"['Running Shoe'"}, 0.183206106870229, 1.5)
# ({"['Running Shoe'", "'Sweatshirts'"}, {"'Socks'"}, 0.183206106870229, 1.5)
# ({"['Running Shoe'"}, {"'Sweatshirts'", "'Swimming Shirt'"}, 0.3816793893129771, 3.0)
# ({"'Swimming Shirt'"}, {"['Running Shoe'", "'Sweatshirts'"}, 0.2748091603053435, 3.0)
# ({"'Sweatshirts'"}, {"['Running Shoe'", "'Swimming Shirt'"}, 0.42748091603053434, 3.0)
# ({"['Running Shoe'", "'Swimming Shirt'"}, {"'Sweatshirts'"}, 0.13740458015267176, 1.5)
# ({"['Running Shoe'", "'Sweatshirts'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Sweatshirts'", "'Swimming Shirt'"}, {"['Running Shoe'"}, 0.12213740458015267, 1.5)
# ({"'Rash Guard'"}, {"['Running Shoe'", "'Sweatshirts'"}, 0.48854961832061067, 3.0)
# ({"['Running Shoe'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.3816793893129771, 3.0)
# ({"'Sweatshirts'"}, {"['Running Shoe'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"['Running Shoe'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.19083969465648856, 1.5)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"['Running Shoe'"}, 0.21374045801526717, 1.5)
# ({"['Running Shoe'", "'Sweatshirts'"}, {"'Rash Guard'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'"}, {"'Soccer Shoe'", "'Tech Pants'"}, 0.42748091603053434, 3.0)
# ({"'Soccer Shoe'"}, {"'Modern Pants'", "'Tech Pants'"}, 0.13740458015267176, 3.0)
# ({"'Tech Pants'"}, {"'Modern Pants'", "'Soccer Shoe'"}, 0.3893129770992366, 3.0)
# ({"'Modern Pants'", "'Soccer Shoe'"}, {"'Tech Pants'"}, 0.061068702290076333, 1.5)
# ({"'Modern Pants'", "'Tech Pants'"}, {"'Soccer Shoe'"}, 0.15267175572519084, 1.5)
# ({"'Soccer Shoe'", "'Tech Pants'"}, {"'Modern Pants'"}, 0.06870229007633588, 1.5)
# ({"['Running Shoe'"}, {"'Rash Guard'", "'Swimming Shirt'"}, 0.3816793893129771, 3.0)
# ({"'Swimming Shirt'"}, {"['Running Shoe'", "'Rash Guard'"}, 0.2748091603053435, 3.0)
# ({"'Rash Guard'"}, {"['Running Shoe'", "'Swimming Shirt'"}, 0.48854961832061067, 3.0)
# ({"['Running Shoe'", "'Swimming Shirt'"}, {"'Rash Guard'"}, 0.13740458015267176, 1.5)
# ({"['Running Shoe'", "'Rash Guard'"}, {"'Swimming Shirt'"}, 0.19083969465648856, 1.5)
# ({"'Rash Guard'", "'Swimming Shirt'"}, {"['Running Shoe'"}, 0.13740458015267176, 1.5)
# ({"'Socks'"}, {"['Running Shoe'", "'Rash Guard'"}, 0.366412213740458, 3.0)
# ({"['Running Shoe'"}, {"'Socks'", "'Rash Guard'"}, 0.3816793893129771, 3.0)
# ({"'Rash Guard'"}, {"'Socks'", "['Running Shoe'"}, 0.48854961832061067, 3.0)
# ({"'Socks'", "['Running Shoe'"}, {"'Rash Guard'"}, 0.183206106870229, 1.5)
# ({"'Socks'", "'Rash Guard'"}, {"['Running Shoe'"}, 0.183206106870229, 1.5)
# ({"['Running Shoe'", "'Rash Guard'"}, {"'Socks'"}, 0.19083969465648856, 1.5)
# ({"'Modern Pants'"}, {"'Sweatshirts'", "'Swimming Shirt'"}, 0.42748091603053434, 3.0)
# ({"'Swimming Shirt'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.2748091603053435, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Swimming Shirt'"}, 0.42748091603053434, 3.0)
# ({"'Modern Pants'", "'Swimming Shirt'"}, {"'Sweatshirts'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Swimming Shirt'"}, 0.21374045801526717, 1.5)
# ({"'Sweatshirts'", "'Swimming Shirt'"}, {"'Modern Pants'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'"}, {"'Rash Guard'", "'Swimming Shirt'"}, 0.42748091603053434, 3.0)
# ({"'Swimming Shirt'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.2748091603053435, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Swimming Shirt'"}, 0.48854961832061067, 3.0)
# ({"'Modern Pants'", "'Swimming Shirt'"}, {"'Rash Guard'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Swimming Shirt'"}, 0.21374045801526717, 1.5)
# ({"'Rash Guard'", "'Swimming Shirt'"}, {"'Modern Pants'"}, 0.13740458015267176, 1.5)
# ({"'Socks'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.366412213740458, 3.0)
# ({"'Modern Pants'"}, {"'Socks'", "'Sweatshirts'"}, 0.42748091603053434, 3.0)
# ({"'Sweatshirts'"}, {"'Socks'", "'Modern Pants'"}, 0.42748091603053434, 3.0)
# ({"'Socks'", "'Modern Pants'"}, {"'Sweatshirts'"}, 0.183206106870229, 1.5)
# ({"'Socks'", "'Sweatshirts'"}, {"'Modern Pants'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Socks'"}, 0.21374045801526717, 1.5)
# ({"'Tech Pants'"}, {"'Rash Guard'", "'Swimming Shirt'"}, 0.3893129770992366, 3.0)
# ({"'Swimming Shirt'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.2748091603053435, 3.0)
# ({"'Rash Guard'"}, {"'Tech Pants'", "'Swimming Shirt'"}, 0.48854961832061067, 3.0)
# ({"'Tech Pants'", "'Swimming Shirt'"}, {"'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Swimming Shirt'"}, 0.19083969465648856, 1.5)
# ({"'Rash Guard'", "'Swimming Shirt'"}, {"'Tech Pants'"}, 0.13740458015267176, 1.5)
# ({"'Rash Guard'"}, {"'Tech Pants'", "'Sweatshirts'"}, 0.48854961832061067, 3.0)
# ({"'Tech Pants'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Sweatshirts'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.19083969465648856, 1.5)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"'Tech Pants'"}, 0.21374045801526717, 1.5)
# ({"'Tech Pants'", "'Sweatshirts'"}, {"'Rash Guard'"}, 0.15267175572519084, 1.5)
# ({"'Soccer Shoe'"}, {"'Tech Pants'", "'Sweatshirts'"}, 0.13740458015267176, 3.0)
# ({"'Tech Pants'"}, {"'Soccer Shoe'", "'Sweatshirts'"}, 0.3893129770992366, 3.0)
# ({"'Sweatshirts'"}, {"'Soccer Shoe'", "'Tech Pants'"}, 0.42748091603053434, 3.0)
# ({"'Soccer Shoe'", "'Tech Pants'"}, {"'Sweatshirts'"}, 0.06870229007633588, 1.5)
# ({"'Soccer Shoe'", "'Sweatshirts'"}, {"'Tech Pants'"}, 0.061068702290076333, 1.5)
# ({"'Tech Pants'", "'Sweatshirts'"}, {"'Soccer Shoe'"}, 0.15267175572519084, 1.5)
# ({"'Modern Pants'"}, {"'Tech Pants'", "'Sweatshirts'"}, 0.42748091603053434, 3.0)
# ({"'Tech Pants'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.3893129770992366, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Tech Pants'"}, 0.42748091603053434, 3.0)
# ({"'Modern Pants'", "'Tech Pants'"}, {"'Sweatshirts'"}, 0.15267175572519084, 1.5)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Tech Pants'"}, 0.21374045801526717, 1.5)
# ({"'Tech Pants'", "'Sweatshirts'"}, {"'Modern Pants'"}, 0.15267175572519084, 1.5)
# ({"'Modern Pants'"}, {"['Running Shoe'", "'Sweatshirts'"}, 0.42748091603053434, 3.0)
# ({"['Running Shoe'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.3816793893129771, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Modern Pants'", "['Running Shoe'"}, {"'Sweatshirts'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"['Running Shoe'"}, 0.21374045801526717, 1.5)
# ({"['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'"}, 0.183206106870229, 1.5)
# ({"'Socks'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.366412213740458, 3.0)
# ({"['Running Shoe'"}, {"'Socks'", "'Modern Pants'"}, 0.3816793893129771, 3.0)
# ({"'Modern Pants'"}, {"'Socks'", "['Running Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Socks'", "['Running Shoe'"}, {"'Modern Pants'"}, 0.183206106870229, 1.5)
# ({"'Socks'", "'Modern Pants'"}, {"['Running Shoe'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'", "['Running Shoe'"}, {"'Socks'"}, 0.183206106870229, 1.5)
# ({"'Rash Guard'"}, {"'Sweatshirts'", "'Swimming Shirt'"}, 0.48854961832061067, 3.0)
# ({"'Swimming Shirt'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.2748091603053435, 3.0)
# ({"'Sweatshirts'"}, {"'Swimming Shirt'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Swimming Shirt'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.13740458015267176, 1.5)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"'Swimming Shirt'"}, 0.21374045801526717, 1.5)
# ({"'Sweatshirts'", "'Swimming Shirt'"}, {"'Rash Guard'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'"}, {"'Sweatshirts'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.48854961832061067, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.21374045801526717, 1.5)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Rash Guard'"}, 0.21374045801526717, 1.5)
# ({"'Sweatshirts'", "'Rash Guard'"}, {"'Modern Pants'"}, 0.21374045801526717, 1.5)
# ({"'Socks'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.366412213740458, 3.0)
# ({"'Tech Pants'"}, {"'Socks'", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Socks'", "'Tech Pants'"}, 0.48854961832061067, 3.0)
# ({"'Socks'", "'Tech Pants'"}, {"'Rash Guard'"}, 0.12213740458015267, 1.5)
# ({"'Socks'", "'Rash Guard'"}, {"'Tech Pants'"}, 0.183206106870229, 1.5)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Socks'"}, 0.19083969465648856, 1.5)
# ({"'Modern Pants'"}, {"'Soccer Shoe'", "'Sweatshirts'"}, 0.42748091603053434, 3.0)
# ({"'Soccer Shoe'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.13740458015267176, 3.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Soccer Shoe'"}, 0.42748091603053434, 3.0)
# ({"'Modern Pants'", "'Soccer Shoe'"}, {"'Sweatshirts'"}, 0.061068702290076333, 1.5)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Soccer Shoe'"}, 0.21374045801526717, 1.5)
# ({"'Soccer Shoe'", "'Sweatshirts'"}, {"'Modern Pants'"}, 0.061068702290076333, 1.5)
# ({"'Modern Pants'"}, {"'Soccer Shoe'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Soccer Shoe'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.13740458015267176, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Soccer Shoe'"}, 0.48854961832061067, 3.0)
# ({"'Modern Pants'", "'Soccer Shoe'"}, {"'Rash Guard'"}, 0.061068702290076333, 1.5)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Soccer Shoe'"}, 0.21374045801526717, 1.5)
# ({"'Soccer Shoe'", "'Rash Guard'"}, {"'Modern Pants'"}, 0.061068702290076333, 1.5)
# ({"'Socks'"}, {"'Modern Pants'", "'Tech Pants'"}, 0.366412213740458, 3.0)
# ({"'Tech Pants'"}, {"'Socks'", "'Modern Pants'"}, 0.3893129770992366, 3.0)
# ({"'Modern Pants'"}, {"'Socks'", "'Tech Pants'"}, 0.42748091603053434, 3.0)
# ({"'Socks'", "'Tech Pants'"}, {"'Modern Pants'"}, 0.12213740458015267, 1.5)
# ({"'Socks'", "'Modern Pants'"}, {"'Tech Pants'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'", "'Tech Pants'"}, {"'Socks'"}, 0.15267175572519084, 1.5)
# ({"'Socks'"}, {"'Sweatshirts'", "'Swimming Shirt'"}, 0.366412213740458, 3.0)
# ({"'Swimming Shirt'"}, {"'Socks'", "'Sweatshirts'"}, 0.2748091603053435, 3.0)
# ({"'Sweatshirts'"}, {"'Socks'", "'Swimming Shirt'"}, 0.42748091603053434, 3.0)
# ({"'Socks'", "'Swimming Shirt'"}, {"'Sweatshirts'"}, 0.12213740458015267, 1.5)
# ({"'Socks'", "'Sweatshirts'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Sweatshirts'", "'Swimming Shirt'"}, {"'Socks'"}, 0.12213740458015267, 1.5)
# ({"'Dry Fit V-Nick']"}, {"'Rash Guard'", "'Hoodies'"}, 0.061068702290076333, 3.0)
# ({"'Rash Guard'"}, {"'Hoodies'", "'Dry Fit V-Nick']"}, 0.48854961832061067, 3.0)
# ({"'Hoodies'"}, {"'Rash Guard'", "'Dry Fit V-Nick']"}, 0.07633587786259542, 3.0)
# ({"'Rash Guard'", "'Dry Fit V-Nick']"}, {"'Hoodies'"}, 0.030534351145038167, 1.5)
# ({"'Hoodies'", "'Dry Fit V-Nick']"}, {"'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Rash Guard'", "'Hoodies'"}, {"'Dry Fit V-Nick']"}, 0.030534351145038167, 1.5)
# ({"['Running Shoe'"}, {"'Tech Pants'", "'Swimming Shirt'"}, 0.3816793893129771, 3.0)
# ({"'Tech Pants'"}, {"['Running Shoe'", "'Swimming Shirt'"}, 0.3893129770992366, 3.0)
# ({"'Swimming Shirt'"}, {"['Running Shoe'", "'Tech Pants'"}, 0.2748091603053435, 3.0)
# ({"['Running Shoe'", "'Tech Pants'"}, {"'Swimming Shirt'"}, 0.13740458015267176, 1.5)
# ({"['Running Shoe'", "'Swimming Shirt'"}, {"'Tech Pants'"}, 0.13740458015267176, 1.5)
# ({"'Tech Pants'", "'Swimming Shirt'"}, {"['Running Shoe'"}, 0.030534351145038167, 1.5)
# ({"'Tech Pants'"}, {"'Rash Guard'", "'Hoodies'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Tech Pants'", "'Hoodies'"}, 0.48854961832061067, 3.0)
# ({"'Hoodies'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.07633587786259542, 3.0)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Hoodies'"}, 0.19083969465648856, 1.5)
# ({"'Tech Pants'", "'Hoodies'"}, {"'Rash Guard'"}, 0.03816793893129771, 1.5)
# ({"'Rash Guard'", "'Hoodies'"}, {"'Tech Pants'"}, 0.030534351145038167, 1.5)
# ({"'Socks'"}, {"'Modern Pants'", "'Swimming Shirt'"}, 0.366412213740458, 3.0)
# ({"'Modern Pants'"}, {"'Socks'", "'Swimming Shirt'"}, 0.42748091603053434, 3.0)
# ({"'Swimming Shirt'"}, {"'Socks'", "'Modern Pants'"}, 0.2748091603053435, 3.0)
# ({"'Socks'", "'Modern Pants'"}, {"'Swimming Shirt'"}, 0.183206106870229, 1.5)
# ({"'Socks'", "'Swimming Shirt'"}, {"'Modern Pants'"}, 0.12213740458015267, 1.5)
# ({"'Modern Pants'", "'Swimming Shirt'"}, {"'Socks'"}, 0.12213740458015267, 1.5)
# ({"['Running Shoe'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.3816793893129771, 3.0)
# ({"'Tech Pants'"}, {"['Running Shoe'", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"['Running Shoe'", "'Tech Pants'"}, 0.48854961832061067, 3.0)
# ({"['Running Shoe'", "'Tech Pants'"}, {"'Rash Guard'"}, 0.13740458015267176, 1.5)
# ({"['Running Shoe'", "'Rash Guard'"}, {"'Tech Pants'"}, 0.19083969465648856, 1.5)
# ({"'Tech Pants'", "'Rash Guard'"}, {"['Running Shoe'"}, 0.19083969465648856, 1.5)
# ({"'Dry Fit V-Nick']"}, {"'Tech Pants'", "'Hoodies'"}, 0.061068702290076333, 3.0)
# ({"'Tech Pants'"}, {"'Hoodies'", "'Dry Fit V-Nick']"}, 0.3893129770992366, 3.0)
# ({"'Hoodies'"}, {"'Tech Pants'", "'Dry Fit V-Nick']"}, 0.07633587786259542, 3.0)
# ({"'Tech Pants'", "'Dry Fit V-Nick']"}, {"'Hoodies'"}, 0.030534351145038167, 1.5)
# ({"'Hoodies'", "'Dry Fit V-Nick']"}, {"'Tech Pants'"}, 0.030534351145038167, 1.5)
# ({"'Tech Pants'", "'Hoodies'"}, {"'Dry Fit V-Nick']"}, 0.03816793893129771, 1.5)
# ({"'Socks'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.366412213740458, 3.0)
# ({"'Modern Pants'"}, {"'Socks'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Rash Guard'"}, {"'Socks'", "'Modern Pants'"}, 0.48854961832061067, 3.0)
# ({"'Socks'", "'Modern Pants'"}, {"'Rash Guard'"}, 0.183206106870229, 1.5)
# ({"'Socks'", "'Rash Guard'"}, {"'Modern Pants'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Socks'"}, 0.21374045801526717, 1.5)
# ({"'Socks'"}, {"['Running Shoe'", "'Tech Pants'"}, 0.366412213740458, 3.0)
# ({"['Running Shoe'"}, {"'Socks'", "'Tech Pants'"}, 0.3816793893129771, 3.0)
# ({"'Tech Pants'"}, {"'Socks'", "['Running Shoe'"}, 0.3893129770992366, 3.0)
# ({"'Socks'", "['Running Shoe'"}, {"'Tech Pants'"}, 0.183206106870229, 1.5)
# ({"'Socks'", "'Tech Pants'"}, {"['Running Shoe'"}, 0.12213740458015267, 1.5)
# ({"['Running Shoe'", "'Tech Pants'"}, {"'Socks'"}, 0.13740458015267176, 1.5)
# ({"'Soccer Shoe'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.13740458015267176, 3.0)
# ({"'Tech Pants'"}, {"'Soccer Shoe'", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Soccer Shoe'", "'Tech Pants'"}, 0.48854961832061067, 3.0)
# ({"'Soccer Shoe'", "'Tech Pants'"}, {"'Rash Guard'"}, 0.06870229007633588, 1.5)
# ({"'Soccer Shoe'", "'Rash Guard'"}, {"'Tech Pants'"}, 0.061068702290076333, 1.5)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Soccer Shoe'"}, 0.19083969465648856, 1.5)
# ({"'Modern Pants'"}, {"['Running Shoe'", "'Tech Pants'"}, 0.42748091603053434, 3.0)
# ({"['Running Shoe'"}, {"'Modern Pants'", "'Tech Pants'"}, 0.3816793893129771, 3.0)
# ({"'Tech Pants'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.3893129770992366, 3.0)
# ({"'Modern Pants'", "['Running Shoe'"}, {"'Tech Pants'"}, 0.183206106870229, 1.5)
# ({"'Modern Pants'", "'Tech Pants'"}, {"['Running Shoe'"}, 0.15267175572519084, 1.5)
# ({"['Running Shoe'", "'Tech Pants'"}, {"'Modern Pants'"}, 0.13740458015267176, 1.5)
# ({"'Modern Pants'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.42748091603053434, 3.0)
# ({"'Tech Pants'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.3893129770992366, 3.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Tech Pants'"}, 0.48854961832061067, 3.0)
# ({"'Modern Pants'", "'Tech Pants'"}, {"'Rash Guard'"}, 0.15267175572519084, 1.5)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Tech Pants'"}, 0.21374045801526717, 1.5)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Modern Pants'"}, 0.19083969465648856, 1.5)
# ({"'Socks'"}, {"['Running Shoe'", "'Swimming Shirt'"}, 0.366412213740458, 3.0)
# ({"['Running Shoe'"}, {"'Socks'", "'Swimming Shirt'"}, 0.3816793893129771, 3.0)
# ...
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Socks'", "['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}, 0.21374045801526717, 3.0)
# ({"'Modern Pants'", "'Swimming Shirt'"}, {"'Socks'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, 0.12213740458015267, 3.0)
# ({"'Socks'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}, 0.183206106870229, 3.0)
# ({"['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "'Swimming Shirt'", "'Rash Guard'"}, 0.183206106870229, 3.0)
# ({"'Rash Guard'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Swimming Shirt'"}, 0.21374045801526717, 3.0)
# ({"'Swimming Shirt'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, 0.12213740458015267, 3.0)
# ({"'Socks'", "['Running Shoe'"}, {"'Modern Pants'", "'Rash Guard'", "'Swimming Shirt'", "'Sweatshirts'"}, 0.183206106870229, 3.0)
# ({"'Socks'", "'Rash Guard'"}, {"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}, 0.183206106870229, 3.0)
# ({"'Socks'", "'Swimming Shirt'"}, {"'Modern Pants'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, 0.12213740458015267, 3.0)
# ({"['Running Shoe'", "'Rash Guard'"}, {"'Modern Pants'", "'Socks'", "'Swimming Shirt'", "'Sweatshirts'"}, 0.19083969465648856, 3.0)
# ({"['Running Shoe'", "'Swimming Shirt'"}, {"'Modern Pants'", "'Rash Guard'", "'Socks'", "'Sweatshirts'"}, 0.13740458015267176, 3.0)
# ({"'Swimming Shirt'", "'Rash Guard'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Sweatshirts'"}, 0.13740458015267176, 3.0)
# ({"'Modern Pants'", "'Socks'", "'Sweatshirts'"}, {"['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "['Running Shoe'", "'Sweatshirts'"}, {"'Socks'", "'Swimming Shirt'", "'Rash Guard'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "'Rash Guard'", "'Sweatshirts'"}, {"'Socks'", "['Running Shoe'", "'Swimming Shirt'"}, 0.10687022900763359, 2.0)
# ({"'Modern Pants'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Socks'", "['Running Shoe'", "'Rash Guard'"}, 0.061068702290076333, 2.0)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'"}, {"'Rash Guard'", "'Swimming Shirt'", "'Sweatshirts'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "'Socks'", "'Rash Guard'"}, {"['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "'Socks'", "'Swimming Shirt'"}, {"'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"'Modern Pants'", "['Running Shoe'", "'Rash Guard'"}, {"'Socks'", "'Swimming Shirt'", "'Sweatshirts'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'"}, {"'Socks'", "'Rash Guard'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"'Modern Pants'", "'Swimming Shirt'", "'Rash Guard'"}, {"'Socks'", "['Running Shoe'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"'Socks'", "['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'", "'Swimming Shirt'", "'Rash Guard'"}, 0.0916030534351145, 2.0)
# ({"'Socks'", "'Rash Guard'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'"}, 0.0916030534351145, 2.0)
# ({"'Socks'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'", "'Rash Guard'"}, 0.061068702290076333, 2.0)
# ({"'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "'Swimming Shirt'"}, 0.0916030534351145, 2.0)
# ({"['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "'Rash Guard'"}, 0.061068702290076333, 2.0)
# ({"'Rash Guard'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'"}, 0.061068702290076333, 2.0)
# ({"'Socks'", "['Running Shoe'", "'Rash Guard'"}, {"'Modern Pants'", "'Swimming Shirt'", "'Sweatshirts'"}, 0.0916030534351145, 2.0)
# ({"'Socks'", "['Running Shoe'", "'Swimming Shirt'"}, {"'Modern Pants'", "'Rash Guard'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"'Socks'", "'Swimming Shirt'", "'Rash Guard'"}, {"'Modern Pants'", "['Running Shoe'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}, {"'Modern Pants'", "'Socks'", "'Sweatshirts'"}, 0.06870229007633588, 2.0)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Sweatshirts'"}, {"'Swimming Shirt'", "'Rash Guard'"}, 0.04580152671755725, 1.5)
# ({"'Modern Pants'", "'Rash Guard'", "'Socks'", "'Sweatshirts'"}, {"['Running Shoe'", "'Swimming Shirt'"}, 0.04580152671755725, 1.5)
# ({"'Modern Pants'", "'Socks'", "'Swimming Shirt'", "'Sweatshirts'"}, {"['Running Shoe'", "'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, {"'Socks'", "'Swimming Shirt'"}, 0.04580152671755725, 1.5)
# ({"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Socks'", "'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Rash Guard'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Socks'", "['Running Shoe'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, {"'Swimming Shirt'", "'Sweatshirts'"}, 0.04580152671755725, 1.5)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Swimming Shirt'"}, {"'Rash Guard'", "'Sweatshirts'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Socks'", "'Swimming Shirt'", "'Rash Guard'"}, {"['Running Shoe'", "'Sweatshirts'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}, {"'Socks'", "'Sweatshirts'"}, 0.030534351145038167, 1.5)
# ({"'Socks'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'", "'Swimming Shirt'"}, 0.04580152671755725, 1.5)
# ({"'Socks'", "['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Socks'", "'Rash Guard'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.030534351145038167, 1.5)
# ({"'Rash Guard'", "['Running Shoe'", "'Swimming Shirt'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'"}, 0.030534351145038167, 1.5)
# ({"'Socks'", "['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, {"'Swimming Shirt'"}, 0.022900763358778626, 1.2)
# ({"'Modern Pants'", "'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Swimming Shirt'"}, {"'Rash Guard'"}, 0.015267175572519083, 1.2)
# ({"'Modern Pants'", "'Sweatshirts'", "'Socks'", "'Rash Guard'", "'Swimming Shirt'"}, {"['Running Shoe'"}, 0.015267175572519083, 1.2)
# ({"'Modern Pants'", "'Sweatshirts'", "['Running Shoe'", "'Rash Guard'", "'Swimming Shirt'"}, {"'Socks'"}, 0.015267175572519083, 1.2)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Swimming Shirt'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.015267175572519083, 1.2)
# ({"'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Rash Guard'", "'Swimming Shirt'"}, {"'Modern Pants'"}, 0.015267175572519083, 1.2)
# ({"'Modern Pants'"}, {"'Sweatshirts'", "'Tech Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, 0.42748091603053434, 6.0)
# ({"'Sweatshirts'"}, {"'Modern Pants'", "'Tech Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, 0.42748091603053434, 6.0)
# ({"'Tech Pants'"}, {"'Modern Pants'", "'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, 0.3893129770992366, 6.0)
# ({"'Socks'"}, {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "['Running Shoe'", "'Rash Guard'"}, 0.366412213740458, 6.0)
# ({"['Running Shoe'"}, {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Socks'", "'Rash Guard'"}, 0.3816793893129771, 6.0)
# ({"'Rash Guard'"}, {"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Socks'", "['Running Shoe'"}, 0.48854961832061067, 6.0)
# ({"'Modern Pants'", "'Sweatshirts'"}, {"'Socks'", "['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}, 0.21374045801526717, 3.0)
# ({"'Modern Pants'", "'Tech Pants'"}, {"'Socks'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, 0.15267175572519084, 3.0)
# ({"'Modern Pants'", "'Socks'"}, {"'Rash Guard'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}, 0.183206106870229, 3.0)
# ({"'Modern Pants'", "['Running Shoe'"}, {"'Socks'", "'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}, 0.183206106870229, 3.0)
# ({"'Modern Pants'", "'Rash Guard'"}, {"'Socks'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}, 0.21374045801526717, 3.0)
# ({"'Tech Pants'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, 0.15267175572519084, 3.0)
# ({"'Socks'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}, 0.183206106870229, 3.0)
# ({"['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "'Tech Pants'", "'Rash Guard'"}, 0.183206106870229, 3.0)
# ({"'Rash Guard'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Tech Pants'"}, 0.21374045801526717, 3.0)
# ({"'Socks'", "'Tech Pants'"}, {"'Modern Pants'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, 0.12213740458015267, 3.0)
# ({"['Running Shoe'", "'Tech Pants'"}, {"'Modern Pants'", "'Rash Guard'", "'Socks'", "'Sweatshirts'"}, 0.13740458015267176, 3.0)
# ({"'Tech Pants'", "'Rash Guard'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Sweatshirts'"}, 0.19083969465648856, 3.0)
# ({"'Socks'", "['Running Shoe'"}, {"'Modern Pants'", "'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}, 0.183206106870229, 3.0)
# ({"'Socks'", "'Rash Guard'"}, {"'Modern Pants'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}, 0.183206106870229, 3.0)
# ({"['Running Shoe'", "'Rash Guard'"}, {"'Modern Pants'", "'Socks'", "'Tech Pants'", "'Sweatshirts'"}, 0.19083969465648856, 3.0)
# ({"'Modern Pants'", "'Tech Pants'", "'Sweatshirts'"}, {"'Socks'", "['Running Shoe'", "'Rash Guard'"}, 0.07633587786259542, 2.0)
# ({"'Modern Pants'", "'Socks'", "'Sweatshirts'"}, {"['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "['Running Shoe'", "'Sweatshirts'"}, {"'Socks'", "'Tech Pants'", "'Rash Guard'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "'Rash Guard'", "'Sweatshirts'"}, {"'Socks'", "['Running Shoe'", "'Tech Pants'"}, 0.10687022900763359, 2.0)
# ({"'Modern Pants'", "'Socks'", "'Tech Pants'"}, {"'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"'Modern Pants'", "['Running Shoe'", "'Tech Pants'"}, {"'Socks'", "'Rash Guard'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"'Modern Pants'", "'Tech Pants'", "'Rash Guard'"}, {"'Socks'", "['Running Shoe'", "'Sweatshirts'"}, 0.07633587786259542, 2.0)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'"}, {"'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "'Socks'", "'Rash Guard'"}, {"['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "['Running Shoe'", "'Rash Guard'"}, {"'Socks'", "'Tech Pants'", "'Sweatshirts'"}, 0.0916030534351145, 2.0)
# ({"'Socks'", "'Tech Pants'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'", "'Rash Guard'"}, 0.061068702290076333, 2.0)
# ({"['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "'Rash Guard'"}, 0.061068702290076333, 2.0)
# ({"'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "['Running Shoe'"}, 0.07633587786259542, 2.0)
# ({"'Socks'", "['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'", "'Tech Pants'", "'Rash Guard'"}, 0.0916030534351145, 2.0)
# ({"'Socks'", "'Rash Guard'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'", "'Tech Pants'"}, 0.0916030534351145, 2.0)
# ({"'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'", "'Tech Pants'"}, 0.0916030534351145, 2.0)
# ({"'Socks'", "['Running Shoe'", "'Tech Pants'"}, {"'Modern Pants'", "'Rash Guard'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"'Socks'", "'Tech Pants'", "'Rash Guard'"}, {"'Modern Pants'", "['Running Shoe'", "'Sweatshirts'"}, 0.061068702290076333, 2.0)
# ({"['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}, {"'Modern Pants'", "'Socks'", "'Sweatshirts'"}, 0.06870229007633588, 2.0)
# ({"'Socks'", "['Running Shoe'", "'Rash Guard'"}, {"'Modern Pants'", "'Tech Pants'", "'Sweatshirts'"}, 0.0916030534351145, 2.0)
# ({"'Modern Pants'", "'Socks'", "'Tech Pants'", "'Sweatshirts'"}, {"['Running Shoe'", "'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}, {"'Socks'", "'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}, {"'Socks'", "['Running Shoe'"}, 0.03816793893129771, 1.5)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Sweatshirts'"}, {"'Tech Pants'", "'Rash Guard'"}, 0.04580152671755725, 1.5)
# ({"'Modern Pants'", "'Rash Guard'", "'Socks'", "'Sweatshirts'"}, {"['Running Shoe'", "'Tech Pants'"}, 0.04580152671755725, 1.5)
# ({"'Modern Pants'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, {"'Socks'", "'Tech Pants'"}, 0.04580152671755725, 1.5)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Tech Pants'"}, {"'Rash Guard'", "'Sweatshirts'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Socks'", "'Tech Pants'", "'Rash Guard'"}, {"['Running Shoe'", "'Sweatshirts'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}, {"'Socks'", "'Sweatshirts'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, {"'Tech Pants'", "'Sweatshirts'"}, 0.04580152671755725, 1.5)
# ({"'Socks'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}, {"'Modern Pants'", "'Rash Guard'"}, 0.030534351145038167, 1.5)
# ({"'Socks'", "'Rash Guard'", "'Tech Pants'", "'Sweatshirts'"}, {"'Modern Pants'", "['Running Shoe'"}, 0.030534351145038167, 1.5)
# ({"'Rash Guard'", "['Running Shoe'", "'Tech Pants'", "'Sweatshirts'"}, {"'Modern Pants'", "'Socks'"}, 0.030534351145038167, 1.5)
# ({"'Socks'", "'Rash Guard'", "['Running Shoe'", "'Sweatshirts'"}, {"'Modern Pants'", "'Tech Pants'"}, 0.04580152671755725, 1.5)
# ({"'Socks'", "['Running Shoe'", "'Tech Pants'", "'Rash Guard'"}, {"'Modern Pants'", "'Sweatshirts'"}, 0.030534351145038167, 1.5)
# ({"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Socks'", "['Running Shoe'"}, {"'Rash Guard'"}, 0.015267175572519083, 1.2)
# ({"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "'Socks'", "'Rash Guard'"}, {"['Running Shoe'"}, 0.015267175572519083, 1.2)
# ({"'Modern Pants'", "'Sweatshirts'", "'Tech Pants'", "['Running Shoe'", "'Rash Guard'"}, {"'Socks'"}, 0.015267175572519083, 1.2)
# ({"'Modern Pants'", "'Sweatshirts'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, {"'Tech Pants'"}, 0.022900763358778626, 1.2)
# ({"'Modern Pants'", "'Tech Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, {"'Sweatshirts'"}, 0.015267175572519083, 1.2)
# ({"'Sweatshirts'", "'Tech Pants'", "'Socks'", "['Running Shoe'", "'Rash Guard'"}, {"'Modern Pants'"}, 0.015267175572519083, 1.2)
#
# Flipkart Frequent Itemsets:
# {"['Mobile Phones'"}
# {"'Televisions'"}
# {"['Laptops'"}
# {"'Washing Machines'"}
# {"'Air Conditioners'"}
# {"'Cameras'"}
# {"'Printers'"}
# {"'Smart Watches']"}
# {"'Refrigerators'"}
# {"'Microwaves'"}
# {"'Cameras'", "'Smart Watches']"}
# {"'Air Conditioners'", "['Mobile Phones'"}
# {"['Mobile Phones'", "'Smart Watches']"}
# {"'Televisions'", "['Laptops'"}
#
# Flipkart Association Rules:
# ({"'Cameras'"}, {"'Smart Watches']"}, 0.14285714285714285, 2.0)
# ({"'Smart Watches']"}, {"'Cameras'"}, 0.21428571428571427, 2.0)
# ({"'Air Conditioners'"}, {"['Mobile Phones'"}, 0.14285714285714285, 2.0)
# ({"['Mobile Phones'"}, {"'Air Conditioners'"}, 0.21428571428571427, 2.0)
# ({"['Mobile Phones'"}, {"'Smart Watches']"}, 0.21428571428571427, 2.0)
# ({"'Smart Watches']"}, {"['Mobile Phones'"}, 0.21428571428571427, 2.0)
# ({"'Televisions'"}, {"['Laptops'"}, 0.14285714285714285, 2.0)
# ({"['Laptops'"}, {"'Televisions'"}, 0.14285714285714285, 2.0)
